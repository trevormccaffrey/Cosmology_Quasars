# %%
#Import necessary packages:
import numpy as np
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import math
from astropy.io import fits
#import linmix
#import corner

# %%
import sys
sys.path.append('/Users/gtr/Work/git/CIV_Distance')
git_path = '/Users/gtr/Work/git/CIV_Distance/'
from CIVfunctions import project,CIV_distance

#Best-fit line -- this part could be improved
#bestfit = np.load("/Users/gtr/Work/git/CIV_Distance/data/RM_CIV_bestFitLine_noScale.npy")[65000:,:]
#bestfit = np.load("/Users/gtr/Work/git/CIV_Distance/data/bestfit_linear.npy")[65000:,:]
#bestfit_log = np.load("/Users/gtr/Work/git/CIV_Distance/data/bestfit_log.npy")
bestfit = np.load("/Users/gtr/Work/git/CIV_Distance/data/bestfit.npy")

# %%
from bokeh.io import output_notebook, output_file, show
from bokeh.plotting import figure
from bokeh.layouts import gridplot, column, row
from bokeh.models import ColumnDataSource, LinearColorMapper, ColorBar, HoverTool
from bokeh.transform import transform
from bokeh.models.widgets import Tabs, Panel

# %%
#%%matplotlib inline

#Set color table:
cmap_rainbow=cm.Spectral
cmap_rainbow_r=cm.Spectral_r

sizeTimlin = 60
sizeChandra = 60
sizeSDSSRM = 60
sizeAll = 15

markerTimlin='o'
markerChandra='^'
markerSDSSRM='*'
markerAll = 'o'

#In case this needs to be adjusted later:
figsize_x=8
figsize_y=8

pheight = pwidth = 280
gheight = gwidth = 10

#Legend size
lsize = '8pt'
#Legend font
lfont = 'Times'
#Legend spacing
lspace = 0 #3 is default
#Legend label_height
lheight = 10 #20 is default
#Legend label_width
lwidth = 10 #20 is default
#Legend margin
lmargin = 5 #10 default

#Desired whitespace for plot limits
whitespace=0.05

c=2.998*10**5

cAll = '#7570b3'
cHST = '#d95f02'
cRM = '#e6ab02'
cNard = '#a6761d'
cGood = '#1b9e77'

visTimlinClean = False
visTimlinOther = False
visLussoClean = False
visLussoOther = False
visSDSSRM = False
visHST = False
visNardini = False
visGood = True

# %%
#Gordon's matplotlib defaults to keep from having to set them for every plot
#and because simply importing richardsplot doesn't seem to work
#Need something like this for Bokeh too.

def figsze(hscale, vscale=0.618034, fig_width_pt = 504.0):
    """Get the fig_width_pt by inserting the textwidth into LaTeX document.
    hscale is fraction of text width you want.
    vscale is fraction of hscale (defaults to golden ratio)  
    """
   
    inches_per_pt = 1.0/72.27                       # Convert pt to inch
    fig_width = fig_width_pt*inches_per_pt*hscale   # width in inches
    fig_height = fig_width*vscale                   # height in inches
    fig_size = [fig_width,fig_height]
    return fig_size

pgf_with_latex = {                      # setup matplotlib to use latex for output
    "axes.linewidth":1.1,               # width of box, 2 is too wide, 1 is too narrow
    "pgf.texsystem": "pdflatex",        # change this if using xetex or lautex
    "text.usetex": False,                # use LaTeX to write all text
    "font.family": "serif",
    "font.serif": [],                   # blank entries should cause plots to inherit fonts from the document
    "font.sans-serif": [],
    "font.monospace": [],
    "axes.labelsize": 20,               # LaTeX default is 10pt font, font size of axis text label
    "axes.labelpad" : 6,                # Distance between label and axis    
    "axes.formatter.limits":[-99,99],   # use sci notation if log10 of axis range is smaller than first or larger than second.
                                        # GTR: Actually *don't* -- should change the axis label instead.  E.g., "Flux Density (10^-17 ergs/s/cm^2)" 
                                        # This is a hack b/c there doesn't seem to be an rcParams version of
                                        # axes.ticklabel_format(style='plain')
    #"axes.formatter.style":"plain",    # Turn off multiplicative offsets (sci notation) to the axes [GTR: Doesn't work]
    "axes.formatter.useoffset":False,   # Turn off additive offsets to the axes
    "font.size": 20,
    "legend.fontsize": 18,              # Make the legend/label fonts a little smaller
    "xtick.labelsize": 20,              # Font size of numbers 
    "ytick.labelsize": 20,
    "xtick.direction": "in",
    "ytick.direction": "in",
    "xtick.minor.visible": True,
    "ytick.minor.visible": True,
    'xtick.major.width':1.0, 
    'xtick.minor.width':1.0, 
    'ytick.major.width':1.0, 
    'ytick.minor.width':1.0, 
    'xtick.major.size':8,             # size of tickmarks in points
    'xtick.minor.size':4, 
    'ytick.major.size':8, 
    'ytick.minor.size':4,
    'xtick.major.pad':8,               # distance between box and numbers
    'ytick.major.pad':8,
    "figure.figsize": figsze(1,1),     # default fig size of 0.9 textwidth
    "pgf.preamble": [
        r"\usepackage[utf8x]{inputenc}",    # use utf8 fonts because your computer can handle it
        r"\usepackage[T1]{fontenc}",        # plots will be generated using this preamble
        ]
    }

mpl.rcParams.update(pgf_with_latex)

import palettable
#csPRGn = palettable.colorbrewer.sequential.PRGn_8.mpl_colors
csPRGn = ['#1b7837', '#5aae61', '#a6dba0', '#c2a5cf', '#9970ab', '#762a83']
csPUOr = ['#b35806', '#e08214', '#fdb863', '#b2abd2', '#8073ac', '#542788'] 
#csDark = palettable.colorbrewer.sequential.PRGn_8.mpl_colors

# %% [markdown]
# Let's read in the Timlin file with Amy Rankine's CIV values and merge that with the Shen+11 catalog file.
#
# Ideally we do this based on coordinates, but since we have SDSS Name in both we can use that instead since it is a bit easier (though could miss a few objects if the names were "computed" incorrectly).

# %%
#Read in necessary data:
#hduAllXray = fits.open('AllXRayDataSensCut.fits') 

#Use "with" syntax for better memory handling
#with fits.open('./AllXRayDataSensCut.fits') as hduAllXray:
#with fits.open('/home/angelica/Research/Paper3/AllXRayDataSensCut.fits') as hduAllXray:
#    headerAllXray = hduAllXray[0].header
#    dataAllXray = hduAllXray[1].data
#    hduAllXray.close()
    
#with fits.open('/home/angelica/Research/Paper3/AllXRayParams_wPerpCIV.fits') as hduAllXray:    
with fits.open('./AllXRayData.fits') as hduAllXray:
    headerAllXray = hduAllXray[0].header
    dataAllXray = hduAllXray[1].data
    hduAllXray.close()

dfAllXray=dataAllXray.byteswap().newbyteorder()  

#Convert numpy arrays to Pandas dataframe
dfAllXray = pd.DataFrame(dataAllXray)

#Fix the fact that some L2500 values are logged and others are not
dfAllXray.loc[dfAllXray.L2500>100, 'L2500'] = np.log10(dfAllXray.loc[dfAllXray.L2500>100, 'L2500'])

#Fix the fact that some f2keV values are logged and others are not
dfAllXray.loc[dfAllXray['f2keV (ergs)']>0 , 'f2keV (ergs)'] = np.log10(dfAllXray.loc[dfAllXray['f2keV (ergs)']>0, 'f2keV (ergs)'])

#Fix the missing L/LEdd values
dfAllXray.loc[dfAllXray.LOGEDD_RATIO<-90, 'LOGEDD_RATIO'] = np.nan

#Fix the missing HeII values
dfAllXray.loc[dfAllXray['HeII EQW']<=0, 'HeII EQW'] = np.nan

#Convert all values of infinity to NaN
dfAllXray.replace([np.inf, -np.inf], np.nan, inplace=True)

#Fix missing new redshift values with old ones
#dfAllXray['z'] = dfAllXray['Redshifts']
#dfAllXray.loc[dfAllXray.Redshifts<0, 'z'] = dfAllXray.loc['Old_redshift']

#Create New Delta Alpha_ox column using revised L_UV - alpha-ox fit
#dfAllXray['New_Delta_Alpha_ox'] = dfAllXray['Alpha_ox'] - (-0.1913*dfAllXray['L2500'] + 4.36996)
#Do this later because it is causing an Endian problem for some unknown reason!

dfAllXray.head()
# Out:
#                       SDSS  LOGEDD_RATIO    Gamma  f2keV (ergs)      L2500  \
# 0  SDSSJ112406.67+061101.4           NaN  1.55415     -31.90487  30.434700
# 1  SDSSJ103337.79+595421.0           NaN  2.30651     -31.82410  30.004999
# 2  SDSSJ014435.54+000131.5         -1.32  1.60380     -32.08018  30.516600
# 3  SDSSJ123234.31+200530.6           NaN  2.52517     -32.19883  30.500299
# 4  SDSSJ143926.32+115528.4         -1.00  2.40415     -31.26537  31.263500
#
#    Alpha_ox  Delta_Alpha_ox  Delg-i  Timlin_CIV_EQW  Timlin_CIV_Blueshift  \
# 0 -1.558645       -0.075139   0.115             NaN                   NaN
# 1 -1.399987       -0.001992   0.111             NaN                   NaN
# 2 -1.604037       -0.104234   0.194             NaN                   NaN
# 3 -1.563276       -0.066716   0.004             NaN                   NaN
# 4 -1.392257        0.256179   0.137             NaN                   NaN
#
# ...

# %%
dfAllXray.head()
# Out:
#                       SDSS  LOGEDD_RATIO    Gamma  f2keV (ergs)      L2500  \
# 0  SDSSJ112406.67+061101.4           NaN  1.55415     -31.90487  30.434700
# 1  SDSSJ103337.79+595421.0           NaN  2.30651     -31.82410  30.004999
# 2  SDSSJ014435.54+000131.5         -1.32  1.60380     -32.08018  30.516600
# 3  SDSSJ123234.31+200530.6           NaN  2.52517     -32.19883  30.500299
# 4  SDSSJ143926.32+115528.4         -1.00  2.40415     -31.26537  31.263500
#
#    Alpha_ox  Delta_Alpha_ox  Delg-i  Timlin_CIV_EQW  Timlin_CIV_Blueshift  \
# 0 -1.558645       -0.075139   0.115             NaN                   NaN
# 1 -1.399987       -0.001992   0.111             NaN                   NaN
# 2 -1.604037       -0.104234   0.194             NaN                   NaN
# 3 -1.563276       -0.066716   0.004             NaN                   NaN
# 4 -1.392257        0.256179   0.137             NaN                   NaN
#
# ...

# %%
print(len(dfAllXray))
# Out:
# 5682

# %% [markdown]
# Make Blueshift plots with Bokeh
#
# There are 4 examples, each adding a level of complexity, so that it is somewhat easier to see what is happening.
#
# I'm sure that there is a way to reduce the number of lines of code by changing the defaults, but I haven't figured that out yet.
#
# Commented out the first 3 since they don't work with the new data file, but they are here for reference.

# %%
#Define the subsets.  These all will have separate legend entries

mask1a = ((dfAllXray['Data_source']==1)&(dfAllXray['Clean']==True)) #Timlin+20; sensitive sample
mask1b = ((dfAllXray['Data_source']==1)&(dfAllXray['Clean']==False)) #Timlin+20; remainder of sample
mask2 = (dfAllXray['Data_source']==2) #Our HST/Chandra
mask3 = (dfAllXray['Data_source']==3) #SDSS-RM
mask4a = ((dfAllXray['Data_source']==4)&(dfAllXray['Clean']==True)) #Lusso+20; clean sample
mask4b = ((dfAllXray['Data_source']==4)&(dfAllXray['Clean']==False)) #Lusso+20; remainder
mask4c  = ((dfAllXray['Data_source']==4)&(dfAllXray['Nardini_Sample']==True)) #Nardini+19 (subset of Lusso+20)

cleanmask = ( ((dfAllXray['Data_source']==1)|(dfAllXray['Data_source']==4)) & (dfAllXray['Clean']==True) )

gammamask = ((dfAllXray['Gamma']>=1.7)&(dfAllXray['Gamma']<=2.8))
daoxmask = ((dfAllXray['Delta_Alpha_ox']>=-0.3)&(dfAllXray['Delta_Alpha_ox']<=0.3))
relgimask = ((dfAllXray['Delg-i']>=-0.3)&(dfAllXray['Delg-i']<=0.3))

#These aren't as restrictive
#gammamask = ((dfAllXray['Gamma']>=1.5)&(dfAllXray['Gamma']<=2.8))
#daoxmask = ((dfAllXray['Delta_Alpha_ox']>=-0.5)&(dfAllXray['Delta_Alpha_ox']<=0.5))
#relgimask = ((dfAllXray['Delg-i']>=-0.5)&(dfAllXray['Delg-i']<=0.5))

#goodmask = (cleanmask&gammamask&daoxmask&relgimask&~mask4c) #Cuts Nardini
goodmask = (cleanmask&gammamask&daoxmask&relgimask)

# %%
#Example with Linked plots, Tabs, and Subsamples

#y = dfAllXray['CIV Blueshift']
SDSS = dfAllXray['SDSS']

#y = np.log10(dfAllXray['CIV_EW'])

logL2500 = dfAllXray['L2500']
z = dfAllXray['Redshifts']

c4blue = dfAllXray['CIV_blue']
c4ew = dfAllXray['CIV_EW']
logc4ew = np.log10(c4ew)
he2ew = np.log10(dfAllXray['HeII EQW'])

gamma = dfAllXray['Gamma']
aox = dfAllXray['Alpha_ox']
daox = dfAllXray['Delta_Alpha_ox']
f2keV = dfAllXray['f2keV (ergs)']

logBHM = dfAllXray['LOGBH']  
logEdd = dfAllXray['LOGEDD_RATIO'] 

relgi = dfAllXray['Delg-i']

# %%
#Create New Delta Alpha_ox column using revised L_UV - alpha-ox fit
ndaox = dfAllXray['Alpha_ox'] - (-0.1913*dfAllXray['L2500'] + 4.36996)

#Using the 'Good' sample to define it
#Angelica's values
ndaox = dfAllXray['Alpha_ox'] - (-0.1657*dfAllXray['L2500'] + 3.5565)


#Using the 'Good' sample to define it
#Gordon's values
ndaox = dfAllXray['Alpha_ox'] - (-0.2135*dfAllXray['L2500'] + 5.056)

#Using the 'Good' sample to define it
#Fitting x vs y instead of y vs x
#ndaox = dfAllXray['Alpha_ox'] - (-0.385*dfAllXray['L2500'] + 10.337)


#If you want to just use the original values!
#ndaox = daox

# %%
print(min(c4blue),max(c4blue),min(c4ew),max(c4ew))
# Out:
# -2585.612245627227 6166.797081979803 5.622421055642074 426.04393342206424

# %%
#Compute CIV distance
c4data = np.array([c4blue, logc4ew]).T
#c4dist = CIV_distance(c4data_log, bestfit, step=1) #compute CIV distances like this

# %%
c4dist, c4perp = CIV_distance(c4data, bestfit, step=1, path=git_path, perp_dist=True)
# Out:
# /Users/gtr/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py:329: UserWarning: Trying to unpickle estimator MinMaxScaler from version 0.24.1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   warnings.warn(

# %%
notbrightmask = (dfAllXray['L2500']<31.9)

X_new = np.array([[29], [33]]) #like X_grid, but just with the endpoints

X = logL2500[goodmask&notbrightmask][:, None]
y = aox[goodmask&notbrightmask]

from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
theta0 = lin_reg.intercept_
theta1 = lin_reg.coef_
print(theta0,theta1)
y_pred2 = lin_reg.predict(X_new)


#Using Angelica's values
y_pred3=-0.1657*X_new+3.5565

#Now fit in the other direction
X2 = aox[goodmask&notbrightmask][:,None]
y2 = logL2500[goodmask&notbrightmask]

X_new2 = np.array([[-1.9], [-1.1]])

lin_reg2 = LinearRegression()
lin_reg2.fit(X2, y2)
theta0n = lin_reg2.intercept_
theta1n = lin_reg2.coef_
print(theta0n,theta1n)
y_pred4 = lin_reg2.predict(X_new2)


#y_pred = ____ + ____*____  # Complete

plt.plot(X_new, y_pred2, "r--", linewidth=2, label="Predictions")
plt.plot(X_new, y_pred3, "g--", linewidth=2, label="Rivera")
plt.plot(y_pred4, X_new2, "k--", linewidth=2, label="Inverse")
#plt.plot(X_grid, y_true, "k-.", label="Actual") #Comment this out to see that it agrees with the above
plt.plot(X, y, "b.", label='Measured')
plt.xlabel("$log L2500$", fontsize=18)
plt.ylabel("$aox$", rotation=0, fontsize=18)
plt.legend(loc="upper right", fontsize=14)
#plt.axis([0, 2, 0, 15])
#save_fig("linear_model_predictions_plot")
plt.show()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# 5.0560034277333035 [-0.21354792]
# 26.824067966879078 [-2.5945107]
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [raw]
# logL2500 = 26.824 + -2.595*aox

# %% [raw]
# aox = -10.337 + -0.385*logL2500

# %% [raw]
# import linmix
#
# #Designate detections if necessary, if not the array is just made up of ones.
# delta_array=np.ones(len(logL2500))
#
# test=linmix.LinMix(logL2500,y=aox,delta=delta_array,K=3,parallelize=True)
#
# test.run_mcmc(silent=True)
#
# #Get the best fit alpha and beta values:
# alpha_med = np.median(test.chain['alpha'])
# beta_med = np.median(test.chain['beta'])
#
# #Number of standard deviations desired for the error bars:
# st_dev = 3
# #Making the contour integrals:
# alpha_std = st_dev*np.std(test.chain['alpha'])
# beta_std = st_dev*np.std(test.chain['beta'])
# beta_sel = (test.chain['beta'] > (beta_med - beta_std)) & (test.chain['beta'] < (beta_med + beta_std))
# alpha_sel = (test.chain['alpha'] > (alpha_med - alpha_std)) & (test.chain['alpha'] < (alpha_med + alpha_std))
#
# x_new = np.arange(29,33,0.01)
# conf_all_y = []
#
# #For all of the fits within the contour intervals, generate corresponding y arrays:
# for i in range(0, len(test.chain['beta'][beta_sel&alpha_sel])):
#     ys = test.chain['alpha'][beta_sel&alpha_sel][i] + x_new * test.chain['beta'][beta_sel&alpha_sel][i]
#     #Put all of the fits in one (2D) array:
#     conf_all_y.append(np.asarray(ys))
#
# conf_all_y = np.asarray(conf_all_y)
# conf_max = []
# conf_min = []
#
# for j in range(len(x_new)):
#     #Now retrieve only the maxmimum and minimum fits.
#     conf_max.append(max(conf_all_y[:,j]))
#     conf_min.append(min(conf_all_y[:,j]))
#
# #This is the best fit:
# xs=logL2500
# ys=np.median(test.chain['alpha'])+xs*np.median(test.chain['beta'])
#
# #standard deviation of the intrinsic scatter
# print(np.sqrt(np.std(test.chain['sigsqr'])))
# #Fit alpha value
# print(np.median(test.chain['alpha']))
# #Fit Beta value
# print(np.median(test.chain['beta']))
# #Error on alpha
# print(np.std(test.chain['alpha']))
# #Error on beta
# print(np.std(test.chain['beta']))

# %%
#dfAllXray['RMID_1'] = '000'

sizeAll=3

#xmin=np.nanmin(x)
#xmax=np.nanmax(x)
#xrange=xmax-xmin
#xlims=[xmin-whitespace*xrange,xmax+whitespace*xrange]

#ymin=np.nanmin(y)
#ymax=np.nanmax(y)
#yrange=ymax-ymin
#ylims=[ymin-whitespace*yrange,ymax+whitespace*yrange]

# create a column data source for the plots to share
source1a = ColumnDataSource(data=dict(logL2500=logL2500[mask1a], z=z[mask1a], c4blue=c4blue[mask1a], c4ew=c4ew[mask1a], \
                                      logc4ew=logc4ew[mask1a], he2ew=he2ew[mask1a], gamma=gamma[mask1a], aox=aox[mask1a], \
                                      daox=daox[mask1a], f2keV=f2keV[mask1a], logBHM=logBHM[mask1a], logEdd=logEdd[mask1a], \
                                    relgi=relgi[mask1a], c4dist=c4dist[mask1a], c4perp=c4perp[mask1a], ndaox=ndaox[mask1a], \
                                    SDSS=SDSS[mask1a]))

source1b = ColumnDataSource(data=dict(logL2500=logL2500[mask1b], z=z[mask1b], c4blue=c4blue[mask1b], c4ew=c4ew[mask1b], \
                                      logc4ew=logc4ew[mask1b], he2ew=he2ew[mask1b], gamma=gamma[mask1b], aox=aox[mask1b], \
                                      daox=daox[mask1b], f2keV=f2keV[mask1b], logBHM=logBHM[mask1b], logEdd=logEdd[mask1b], \
                                    relgi=relgi[mask1b], c4dist=c4dist[mask1b], c4perp=c4perp[mask1b], ndaox=ndaox[mask1b], \
                                    SDSS=SDSS[mask1b]))

source2 = ColumnDataSource(data=dict(logL2500=logL2500[mask2], z=z[mask2], c4blue=c4blue[mask2], c4ew=c4ew[mask2], \
                                      logc4ew=logc4ew[mask2], he2ew=he2ew[mask2], gamma=gamma[mask2], aox=aox[mask2], \
                                      daox=daox[mask2], f2keV=f2keV[mask2], logBHM=logBHM[mask2], logEdd=logEdd[mask2], \
                                    relgi=relgi[mask2], c4dist=c4dist[mask2], c4perp=c4perp[mask2], ndaox=ndaox[mask2], \
                                    SDSS=SDSS[mask2]))

source3 = ColumnDataSource(data=dict(logL2500=logL2500[mask3], z=z[mask3], c4blue=c4blue[mask3], c4ew=c4ew[mask3], \
                                      logc4ew=logc4ew[mask3], he2ew=he2ew[mask3], gamma=gamma[mask3], aox=aox[mask3], \
                                      daox=daox[mask3], f2keV=f2keV[mask3], logBHM=logBHM[mask3], logEdd=logEdd[mask3], \
                                    relgi=relgi[mask3], c4dist=c4dist[mask3], c4perp=c4perp[mask3], ndaox=ndaox[mask3], \
                                    SDSS=SDSS[mask3]))

source4a = ColumnDataSource(data=dict(logL2500=logL2500[mask4a], z=z[mask4a], c4blue=c4blue[mask4a], c4ew=c4ew[mask4a], \
                                      logc4ew=logc4ew[mask4a], he2ew=he2ew[mask4a], gamma=gamma[mask4a], aox=aox[mask4a], \
                                      daox=daox[mask4a], f2keV=f2keV[mask4a], logBHM=logBHM[mask4a], logEdd=logEdd[mask4a], \
                                    relgi=relgi[mask4a], c4dist=c4dist[mask4a], c4perp=c4perp[mask4a], ndaox=ndaox[mask4a], \
                                    SDSS=SDSS[mask4a]))

source4b = ColumnDataSource(data=dict(logL2500=logL2500[mask4b], z=z[mask4b], c4blue=c4blue[mask4b], c4ew=c4ew[mask4b], \
                                      logc4ew=logc4ew[mask4b], he2ew=he2ew[mask4b], gamma=gamma[mask4b], aox=aox[mask4b], \
                                      daox=daox[mask4b], f2keV=f2keV[mask4b], logBHM=logBHM[mask4b], logEdd=logEdd[mask4b], \
                                    relgi=relgi[mask4b], c4dist=c4dist[mask4b], c4perp=c4perp[mask4b], ndaox=ndaox[mask4b], \
                                    SDSS=SDSS[mask4b]))

source4c = ColumnDataSource(data=dict(logL2500=logL2500[mask4c], z=z[mask4c], c4blue=c4blue[mask4c], c4ew=c4ew[mask4c], \
                                      logc4ew=logc4ew[mask4c], he2ew=he2ew[mask4c], gamma=gamma[mask4c], aox=aox[mask4c], \
                                      daox=daox[mask4c], f2keV=f2keV[mask4c], logBHM=logBHM[mask4c], logEdd=logEdd[mask4c], \
                                    relgi=relgi[mask4c], c4dist=c4dist[mask4c], c4perp=c4perp[mask4c], ndaox=ndaox[mask4c], \
                                    SDSS=SDSS[mask4c]))

sourcegood = ColumnDataSource(data=dict(logL2500=logL2500[goodmask], z=z[goodmask], c4blue=c4blue[goodmask], c4ew=c4ew[goodmask], \
                                      logc4ew=logc4ew[goodmask], he2ew=he2ew[goodmask], gamma=gamma[goodmask], aox=aox[goodmask], \
                                      daox=daox[goodmask], f2keV=f2keV[goodmask], logBHM=logBHM[goodmask], logEdd=logEdd[goodmask], \
                                    relgi=relgi[goodmask], c4dist=c4dist[goodmask], c4perp=c4perp[goodmask], ndaox=ndaox[goodmask], \
                                    SDSS=SDSS[goodmask]))

TOOLS = "box_select,lasso_select,pan,wheel_zoom,box_zoom,hover,reset,help"

#TOOLTIPS=[
#            ('RMID', '@RMID'),
#            ('z', '@z')
#            ]

TOOLTIPS=[
            ('Name', '@SDSS'),
            ('z', '@z')
            ]

color_mapper = LinearColorMapper(palette="Viridis256", low=logL2500.min(), high=logL2500.max())
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=12, location=(0,0), title='L2500')

# %% [markdown]
# Let's make plots with the following y-axes:
#
# CIV distance
# CIV blueshift
# L2500
#
# These vs.
# CIV blueshift
# CIV EW
# HeII EW
# CIV distance
#
# Gamma
# aox
# daox
#
# Delta(g-i)
# L2500
# LOGEDD_RATIO
# LOGBH
#
# f2keV?
#
#
# Then also need a MISC Tab with
# Gamma vs. doax
# L2500 vs. z

# %%
#CIV Distance Panel

c1 = {}
# create a new plot
p1 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c1['TimlinClean'] = p1.circle('c4blue', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c1['TimlinOther'] = p1.circle('c4blue', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c1['LussoClean'] = p1.circle('c4blue', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c1['LussoOther'] = p1.circle('c4blue', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c1['SDSSRM'] = p1.circle('c4blue', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c1['HST'] = p1.circle('c4blue', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c1['Nardini'] = p1.circle('c4blue', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c1['Good'] = p1.circle('c4blue', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p1.yaxis.axis_label = 'CIV Distance'
p1.xaxis.axis_label = 'Blueshift'
p1.legend.click_policy="hide"
p1.legend.glyph_height = gheight
p1.legend.spacing = lspace
p1.legend.label_text_font = lfont
p1.legend.label_text_font_size = lsize
p1.legend.label_height = lheight
p1.legend.label_width = lwidth
p1.legend.margin = lmargin
p1.legend.location = 'top_left'
c1['TimlinClean'].visible = visTimlinClean
c1['TimlinOther'].visible = visTimlinOther
c1['LussoClean'].visible = visLussoClean
c1['LussoOther'].visible = visLussoOther
c1['SDSSRM'].visible = visSDSSRM
c1['HST'].visible = visHST
c1['Nardini'].visible = visNardini

c2 = {}
p2 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c2['TimlinClean'] = p2.circle('logc4ew', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c2['TimlinOther'] = p2.circle('logc4ew', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c2['LussoClean'] = p2.circle('logc4ew', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c2['LussoOther'] = p2.circle('logc4ew', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c2['SDSSRM'] = p2.circle('logc4ew', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c2['HST'] = p2.circle('logc4ew', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c2['Nardini'] = p2.circle('logc4ew', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c2['Good'] = p2.circle('logc4ew', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p2.yaxis.axis_label = 'CIV Distance'
p2.xaxis.axis_label = 'log(CIV EW)'
p2.legend.click_policy="hide"
p2.legend.glyph_height = gheight
p2.legend.spacing = lspace
p2.legend.label_text_font = lfont
p2.legend.label_text_font_size = lsize
p2.legend.label_height = lheight
p2.legend.label_width = lwidth
p2.legend.margin = lmargin
p2.legend.location = 'top_right'
c2['TimlinClean'].visible = visTimlinClean
c2['TimlinOther'].visible = visTimlinOther
c2['LussoClean'].visible = visLussoClean
c2['LussoOther'].visible = visLussoOther
c2['SDSSRM'].visible = visSDSSRM
c2['HST'].visible = visHST
c2['Nardini'].visible = visNardini

c3 = {}
p3 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c3['TimlinClean'] = p3.circle('he2ew', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c3['TimlinOther'] = p3.circle('he2ew', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c3['LussoClean'] = p3.circle('he2ew', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c3['LussoOther'] = p3.circle('he2ew', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c3['SDSSRM'] = p3.circle('he2ew', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c3['HST'] = p3.circle('he2ew', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c3['Nardini'] = p3.circle('he2ew', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c3['Good'] = p3.circle('he2ew', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p3.yaxis.axis_label = 'CIV Distance'
p3.xaxis.axis_label = 'log(HeII EQW)'
p3.legend.click_policy="hide"
p3.legend.glyph_height = gheight
p3.legend.spacing = lspace
p3.legend.label_text_font = lfont
p3.legend.label_text_font_size = lsize
p3.legend.label_height = lheight
p3.legend.label_width = lwidth
p3.legend.margin = lmargin
p3.legend.location = 'top_right'
c3['TimlinClean'].visible = visTimlinClean
c3['TimlinOther'].visible = visTimlinOther
c3['LussoClean'].visible = visLussoClean
c3['LussoOther'].visible = visLussoOther
c3['SDSSRM'].visible = visSDSSRM
c3['HST'].visible = visHST
c3['Nardini'].visible = visNardini

#selection_glyph = Circle(fill_color='orange', line_color=None)
#nonselection_glyph = Circle(fill_color='#1f77b4', fill_alpha=0.1, line_color=None)
#r1.selection_glyph = selection_glyph
#r1.nonselection_glyph = nonselection_glyph

c4 = {}
p4 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.5), y_range=(-1500,6500))
c4['TimlinClean'] = p4.circle('gamma', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c4['TimlinOther'] = p4.circle('gamma', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c4['LussoClean'] = p4.circle('gamma', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c4['LussoOther'] = p4.circle('gamma', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c4['SDSSRM'] = p4.circle('gamma', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c4['HST'] = p4.circle('gamma', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c4['Nardini'] = p4.circle('gamma', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c4['Good'] = p4.circle('gamma', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p4.yaxis.axis_label = 'CIV Distance'
p4.xaxis.axis_label = 'Gamma'
#p6.x_range.flipped = True
p4.legend.click_policy="hide"
p4.legend.glyph_height = gheight
p4.legend.spacing = lspace
p4.legend.label_text_font = lfont
p4.legend.label_text_font_size = lsize
p4.legend.label_height = lheight
p4.legend.label_width = lwidth
p4.legend.margin = lmargin
p4.legend.location = 'top_right'
c4['TimlinClean'].visible = visTimlinClean
c4['TimlinOther'].visible = visTimlinOther
c4['LussoClean'].visible = visLussoClean
c4['LussoOther'].visible = visLussoOther
c4['SDSSRM'].visible = visSDSSRM
c4['HST'].visible = visHST
c4['Nardini'].visible = visNardini

c5 = {}
p5 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c5['TimlinClean'] = p5.circle('aox', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c5['TimlinOther'] = p5.circle('aox', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c5['LussoClean'] = p5.circle('aox', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c5['LussoOther'] = p5.circle('aox', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c5['SDSSRM'] = p5.circle('aox', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c5['HST'] = p5.circle('aox', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c5['Nardini'] = p5.circle('aox', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c5['Good'] = p5.circle('aox', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p5.yaxis.axis_label = 'CIV Distance'
p5.xaxis.axis_label = 'alpha_ox'
#p5.x_range.flipped = True
p5.legend.click_policy="hide"
p5.legend.glyph_height = gheight
p5.legend.spacing = lspace
p5.legend.label_text_font = lfont
p5.legend.label_text_font_size = lsize
p5.legend.label_height = lheight
p5.legend.label_width = lwidth
p5.legend.margin = lmargin
p5.legend.location = 'top_right'
c5['TimlinClean'].visible = visTimlinClean
c5['TimlinOther'].visible = visTimlinOther
c5['LussoClean'].visible = visLussoClean
c5['LussoOther'].visible = visLussoOther
c5['SDSSRM'].visible = visSDSSRM
c5['HST'].visible = visHST
c5['Nardini'].visible = visNardini

c6 = {}
p6 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c6['TimlinClean'] = p6.circle('ndaox', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c6['TimlinOther'] = p6.circle('ndaox', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c6['LussoClean'] = p6.circle('ndaox', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c6['LussoOther'] = p6.circle('ndaox', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c6['SDSSRM'] = p6.circle('ndaox', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c6['HST'] = p6.circle('ndaox', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c6['Nardini'] = p6.circle('ndaox', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c6['Good'] = p6.circle('ndaox', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p6.yaxis.axis_label = 'CIV Distance'
p6.xaxis.axis_label = 'delta_aox'
#p5.x_range.flipped = True
p6.legend.click_policy="hide"
p6.legend.glyph_height = gheight
p6.legend.spacing = lspace
p6.legend.label_text_font = lfont
p6.legend.label_text_font_size = lsize
p6.legend.label_height = lheight
p6.legend.label_width = lwidth
p6.legend.margin = lmargin
p6.legend.location = 'top_right'
c6['TimlinClean'].visible = visTimlinClean
c6['TimlinOther'].visible = visTimlinOther
c6['LussoClean'].visible = visLussoClean
c6['LussoOther'].visible = visLussoOther
c6['SDSSRM'].visible = visSDSSRM
c6['HST'].visible = visHST
c6['Nardini'].visible = visNardini


c7 = {}
p7 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c7['TimlinClean'] = p7.circle('logL2500', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c7['TimlinOther'] = p7.circle('logL2500', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c7['LussoClean'] = p7.circle('logL2500', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c7['LussoOther'] = p7.circle('logL2500', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c7['SDSSRM'] = p7.circle('logL2500', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c7['HST'] = p7.circle('logL2500', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c7['Nardini'] = p7.circle('logL2500', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c7['Good'] = p7.circle('logL2500', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p7.yaxis.axis_label = 'CIV Distance'
p7.xaxis.axis_label = 'logL2500'
#p5.x_range.flipped = True
p7.legend.click_policy="hide"
p7.legend.glyph_height = gheight
p7.legend.spacing = lspace
p7.legend.label_text_font = lfont
p7.legend.label_text_font_size = lsize
p7.legend.label_height = lheight
p7.legend.label_width = lwidth
p7.legend.margin = lmargin
p7.legend.location = 'top_left'
c7['TimlinClean'].visible = visTimlinClean
c7['TimlinOther'].visible = visTimlinOther
c7['LussoClean'].visible = visLussoClean
c7['LussoOther'].visible = visLussoOther
c7['SDSSRM'].visible = visSDSSRM
c7['HST'].visible = visHST
c7['Nardini'].visible = visNardini

c8 = {}
p8 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(-35, -29))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c8['TimlinClean'] = p8.circle('f2keV', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8['TimlinOther'] = p8.circle('f2keV', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8['LussoClean'] = p8.circle('f2keV', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8['LussoOther'] = p8.circle('f2keV', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8['SDSSRM'] = p8.circle('f2keV', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c8['HST'] = p8.circle('f2keV', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c8['Nardini'] = p8.circle('f2keV', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c8['Good'] = p8.circle('f2keV', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p8.yaxis.axis_label = 'CIV Distance'
p8.xaxis.axis_label = 'log f 2keV'
#p5.x_range.flipped = True
p8.legend.click_policy="hide"
p8.legend.glyph_height = gheight
p8.legend.spacing = lspace
p8.legend.label_text_font = lfont
p8.legend.label_text_font_size = lsize
p8.legend.label_height = lheight
p8.legend.label_width = lwidth
p8.legend.margin = lmargin
p8.legend.location = 'top_left'
c8['TimlinClean'].visible = visTimlinClean
c8['TimlinOther'].visible = visTimlinOther
c8['LussoClean'].visible = visLussoClean
c8['LussoOther'].visible = visLussoOther
c8['SDSSRM'].visible = visSDSSRM
c8['HST'].visible = visHST
c8['Nardini'].visible = visNardini

c8b = {}
p8b = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c8b['TimlinClean'] = p8b.circle('c4perp', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8b['TimlinOther'] = p8b.circle('c4perp', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8b['LussoClean'] = p8b.circle('c4perp', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8b['LussoOther'] = p8b.circle('c4perp', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c8b['SDSSRM'] = p8b.circle('c4perp', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c8b['HST'] = p8b.circle('c4perp', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c8b['Nardini'] = p8b.circle('c4perp', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c8b['Good'] = p8b.circle('c4perp', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p8b.yaxis.axis_label = 'CIV Distance'
p8b.xaxis.axis_label = 'CIV Perp Dist'
#p5.x_range.flipped = True
p8b.legend.click_policy="hide"
p8b.legend.glyph_height = gheight
p8b.legend.spacing = lspace
p8b.legend.label_text_font = lfont
p8b.legend.label_text_font_size = lsize
p8b.legend.label_height = lheight
p8b.legend.label_width = lwidth
p8b.legend.margin = lmargin
p8b.legend.location = 'top_left'
c8b['TimlinClean'].visible = visTimlinClean
c8b['TimlinOther'].visible = visTimlinOther
c8b['LussoClean'].visible = visLussoClean
c8b['LussoOther'].visible = visLussoOther
c8b['SDSSRM'].visible = visSDSSRM
c8b['HST'].visible = visHST
c8b['Nardini'].visible = visNardini


c9 = {}
p9 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c9['TimlinClean'] = p9.circle('logEdd', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c9['TimlinOther'] = p9.circle('logEdd', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c9['LussoClean'] = p9.circle('logEdd', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c9['LussoOther'] = p9.circle('logEdd', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c9['SDSSRM'] = p9.circle('logEdd', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c9['HST'] = p9.circle('logEdd', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c9['Nardini'] = p9.circle('logEdd', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c9['Good'] = p9.circle('logEdd', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p9.yaxis.axis_label = 'CIV Distance'
p9.xaxis.axis_label = 'logEdd'
#p5.x_range.flipped = True
p9.legend.click_policy="hide"
p9.legend.glyph_height = gheight
p9.legend.spacing = lspace
p9.legend.label_text_font = lfont
p9.legend.label_text_font_size = lsize
p9.legend.label_height = lheight
p9.legend.label_width = lwidth
p9.legend.margin = lmargin
p9.legend.location = 'top_left'
c9['TimlinClean'].visible = visTimlinClean
c9['TimlinOther'].visible = visTimlinOther
c9['LussoClean'].visible = visLussoClean
c9['LussoOther'].visible = visLussoOther
c9['SDSSRM'].visible = visSDSSRM
c9['HST'].visible = visHST
c9['Nardini'].visible = visNardini

c10 = {}
p10 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(7, 11))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c10['TimlinClean'] = p10.circle('logBHM', 'c4dist', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c10['TimlinOther'] = p10.circle('logBHM', 'c4dist', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c10['LussoClean'] = p10.circle('logBHM', 'c4dist', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c10['LussoOther'] = p10.circle('logBHM', 'c4dist', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c10['SDSSRM'] = p10.circle('logBHM', 'c4dist', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c10['HST'] = p10.circle('logBHM', 'c4dist', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c10['Nardini'] = p10.circle('logBHM', 'c4dist', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c10['Good'] = p10.circle('logBHM', 'c4dist', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p10.yaxis.axis_label = 'CIV Distance'
p10.yaxis.axis_label = 'CIV Distance'
p10.xaxis.axis_label = 'logBHM'
#p5.x_range.flipped = True
p10.legend.click_policy="hide"
p10.legend.glyph_height = gheight
p10.legend.spacing = lspace
p10.legend.label_text_font = lfont
p10.legend.label_text_font_size = lsize
p10.legend.label_height = lheight
p10.legend.label_width = lwidth
p10.legend.margin = lmargin
p10.legend.location = 'top_left'
c10['TimlinClean'].visible = visTimlinClean
c10['TimlinOther'].visible = visTimlinOther
c10['LussoClean'].visible = visLussoClean
c10['LussoOther'].visible = visLussoOther
c10['SDSSRM'].visible = visSDSSRM
c10['HST'].visible = visHST
c10['Nardini'].visible = visNardini


# put all the plots in a gridplot
p = gridplot([[p1, p2, p3], [p4, p5, p6], [p7, p8, p8b],  [p9, p10, ]], sizing_mode='scale_width')

tab1 = Panel(child = p, title = 'CIV Distance')

# %%
#CIV Blueshift Panel

c11 = {}
# create a new plot
p11 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c11['TimlinClean'] = p11.circle('c4dist', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c11['TimlinOther'] = p11.circle('c4dist', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c11['LussoClean'] = p11.circle('c4dist', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c11['LussoOther'] = p11.circle('c4dist', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c11['SDSSRM'] = p11.circle('c4dist', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c11['HST'] = p11.circle('c4dist', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c11['Nardini'] = p11.circle('c4dist', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c11['Good'] = p11.circle('c4dist', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p11.yaxis.axis_label = 'Blueshift'
p11.xaxis.axis_label = 'CIV Distance'
p11.legend.click_policy="hide"
p11.legend.glyph_height = gheight
p11.legend.spacing = lspace
p11.legend.label_text_font = lfont
p11.legend.label_text_font_size = lsize
p11.legend.label_height = lheight
p11.legend.label_width = lwidth
p11.legend.margin = lmargin
p11.legend.location = 'top_left'
c11['TimlinClean'].visible = visTimlinClean
c11['TimlinOther'].visible = visTimlinOther
c11['LussoClean'].visible = visLussoClean
c11['LussoOther'].visible = visLussoOther
c11['SDSSRM'].visible = visSDSSRM
c11['HST'].visible = visHST
c11['Nardini'].visible = visNardini

c12 = {}
p12 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c12['TimlinClean'] = p12.circle('logc4ew', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c12['TimlinOther'] = p12.circle('logc4ew', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c12['LussoClean'] = p12.circle('logc4ew', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c12['LussoOther'] = p12.circle('logc4ew', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c12['SDSSRM'] = p12.circle('logc4ew', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c12['HST'] = p12.circle('logc4ew', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c12['Nardini'] = p12.circle('logc4ew', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c12['Good'] = p12.circle('logc4ew', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p12.yaxis.axis_label = 'Blueshift'
p12.xaxis.axis_label = 'log(CIV EW)'
p12.x_range.flipped = True
p12.legend.click_policy="hide"
p12.legend.glyph_height = gheight
p12.legend.spacing = lspace
p12.legend.label_text_font = lfont
p12.legend.label_text_font_size = lsize
p12.legend.label_height = lheight
p12.legend.label_width = lwidth
p12.legend.margin = lmargin
p12.legend.location = 'top_left'
c12['TimlinClean'].visible = visTimlinClean
c12['TimlinOther'].visible = visTimlinOther
c12['LussoClean'].visible = visLussoClean
c12['LussoOther'].visible = visLussoOther
c12['SDSSRM'].visible = visSDSSRM
c12['HST'].visible = visHST
c12['Nardini'].visible = visNardini

c13 = {}
p13 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c13['TimlinClean'] = p13.circle('he2ew', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c13['TimlinOther'] = p13.circle('he2ew', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c13['LussoClean'] = p13.circle('he2ew', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c13['LussoOther'] = p13.circle('he2ew', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c13['SDSSRM'] = p13.circle('he2ew', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c13['HST'] = p13.circle('he2ew', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c13['Nardini'] = p13.circle('he2ew', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c13['Good'] = p13.circle('he2ew', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p13.yaxis.axis_label = 'Blueshift'
p13.xaxis.axis_label = 'log(HeII EQW)'
p13.x_range.flipped = True
p13.legend.click_policy="hide"
p13.legend.glyph_height = gheight
p13.legend.spacing = lspace
p13.legend.label_text_font = lfont
p13.legend.label_text_font_size = lsize
p13.legend.label_height = lheight
p13.legend.label_width = lwidth
p13.legend.margin = lmargin
p13.legend.location = 'top_left'
c13['TimlinClean'].visible = visTimlinClean
c13['TimlinOther'].visible = visTimlinOther
c13['LussoClean'].visible = visLussoClean
c13['LussoOther'].visible = visLussoOther
c13['SDSSRM'].visible = visSDSSRM
c13['HST'].visible = visHST
c13['Nardini'].visible = visNardini
                           

c14 = {}
p14 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.5), y_range=(-1500,6500))
c14['TimlinClean'] = p14.circle('gamma', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c14['TimlinOther'] = p14.circle('gamma', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c14['LussoClean'] = p14.circle('gamma', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c14['LussoOther'] = p14.circle('gamma', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c14['SDSSRM'] = p14.circle('gamma', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c14['HST'] = p14.circle('gamma', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c14['Nardini'] = p14.circle('gamma', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c14['Good'] = p14.circle('gamma', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p14.yaxis.axis_label = 'Blueshift'
p14.xaxis.axis_label = 'Gamma'
#p6.x_range.flipped = True
p14.legend.click_policy="hide"
p14.legend.glyph_height = gheight
p14.legend.spacing = lspace
p14.legend.label_text_font = lfont
p14.legend.label_text_font_size = lsize
p14.legend.label_height = lheight
p14.legend.label_width = lwidth
p14.legend.margin = lmargin
p14.legend.location = 'top_right'
c14['TimlinClean'].visible = visTimlinClean
c14['TimlinOther'].visible = visTimlinOther
c14['LussoClean'].visible = visLussoClean
c14['LussoOther'].visible = visLussoOther
c14['SDSSRM'].visible = visSDSSRM
c14['HST'].visible = visHST
c14['Nardini'].visible = visNardini

c15 = {}
p15 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c15['TimlinClean'] = p15.circle('aox', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c15['TimlinOther'] = p15.circle('aox', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c15['LussoClean'] = p15.circle('aox', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c15['LussoOther'] = p15.circle('aox', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c15['SDSSRM'] = p15.circle('aox', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c15['HST'] = p15.circle('aox', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c15['Nardini'] = p15.circle('aox', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c15['Good'] = p15.circle('aox', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p15.yaxis.axis_label = 'Blueshift'
p15.xaxis.axis_label = 'alpha_ox'
p15.x_range.flipped = True
p15.legend.click_policy="hide"
p15.legend.glyph_height = gheight
p15.legend.spacing = lspace
p15.legend.label_text_font = lfont
p15.legend.label_text_font_size = lsize
p15.legend.label_height = lheight
p15.legend.label_width = lwidth
p15.legend.margin = lmargin
p15.legend.location = 'top_right'
c15['TimlinClean'].visible = visTimlinClean
c15['TimlinOther'].visible = visTimlinOther
c15['LussoClean'].visible = visLussoClean
c15['LussoOther'].visible = visLussoOther
c15['SDSSRM'].visible = visSDSSRM
c15['HST'].visible = visHST
c15['Nardini'].visible = visNardini

c16 = {}
p16 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c16['TimlinClean'] = p16.circle('ndaox', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c16['TimlinOther'] = p16.circle('ndaox', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c16['LussoClean'] = p16.circle('ndaox', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c16['LussoOther'] = p16.circle('ndaox', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c16['SDSSRM'] = p16.circle('ndaox', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c16['HST'] = p16.circle('ndaox', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c16['Nardini'] = p16.circle('ndaox', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c16['Good'] = p16.circle('ndaox', 'c4blue', source=sourcegood, legend_label='good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p16.yaxis.axis_label = 'Blueshift'
p16.xaxis.axis_label = 'delta_aox'
p16.x_range.flipped = True
p16.legend.click_policy="hide"
p16.legend.glyph_height = gheight
p16.legend.spacing = lspace
p16.legend.label_text_font = lfont
p16.legend.label_text_font_size = lsize
p16.legend.label_height = lheight
p16.legend.label_width = lwidth
p16.legend.margin = lmargin
p16.legend.location = 'top_right'
c16['TimlinClean'].visible = visTimlinClean
c16['TimlinOther'].visible = visTimlinOther
c16['LussoClean'].visible = visLussoClean
c16['LussoOther'].visible = visLussoOther
c16['SDSSRM'].visible = visSDSSRM
c16['HST'].visible = visHST
c16['Nardini'].visible = visNardini


c17 = {}
p17 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c17['TimlinClean'] = p17.circle('logL2500', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c17['TimlinOther'] = p17.circle('logL2500', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c17['LussoClean'] = p17.circle('logL2500', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c17['LussoOther'] = p17.circle('logL2500', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c17['SDSSRM'] = p17.circle('logL2500', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c17['HST'] = p17.circle('logL2500', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c17['Nardini'] = p17.circle('logL2500', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c17['Good'] = p17.circle('logL2500', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p17.yaxis.axis_label = 'Blueshift'
p17.xaxis.axis_label = 'logL2500'
#p5.x_range.flipped = True
p17.legend.click_policy="hide"
p17.legend.glyph_height = gheight
p17.legend.spacing = lspace
p17.legend.label_text_font = lfont
p17.legend.label_text_font_size = lsize
p17.legend.label_height = lheight
p17.legend.label_width = lwidth
p17.legend.margin = lmargin
p17.legend.location = 'top_left'
c17['TimlinClean'].visible = visTimlinClean
c17['TimlinOther'].visible = visTimlinOther
c17['LussoClean'].visible = visLussoClean
c17['LussoOther'].visible = visLussoOther
c17['SDSSRM'].visible = visSDSSRM
c17['HST'].visible = visHST
c17['Nardini'].visible = visNardini

c18 = {}
p18 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(-35, -29))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c18['TimlinClean'] = p18.circle('f2keV', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18['TimlinOther'] = p18.circle('f2keV', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18['LussoClean'] = p18.circle('f2keV', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18['LussoOther'] = p18.circle('f2keV', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18['SDSSRM'] = p18.circle('f2keV', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c18['HST'] = p18.circle('f2keV', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c18['Nardini'] = p18.circle('f2keV', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c18['Good'] = p18.circle('f2keV', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p18.yaxis.axis_label = 'Blueshift'
p18.xaxis.axis_label = 'log f 2keV'
#p5.x_range.flipped = True
p18.legend.click_policy="hide"
p18.legend.glyph_height = gheight
p18.legend.spacing = lspace
p18.legend.label_text_font = lfont
p18.legend.label_text_font_size = lsize
p18.legend.label_height = lheight
p18.legend.label_width = lwidth
p18.legend.margin = lmargin
p18.legend.location = 'top_left'
c18['TimlinClean'].visible = visTimlinClean
c18['TimlinOther'].visible = visTimlinOther
c18['LussoClean'].visible = visLussoClean
c18['LussoOther'].visible = visLussoOther
c18['SDSSRM'].visible = visSDSSRM
c18['HST'].visible = visHST
c18['Nardini'].visible = visNardini

c18b = {}
p18b = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c18b['TimlinClean'] = p18b.circle('c4perp', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18b['TimlinOther'] = p18b.circle('c4perp', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18b['LussoClean'] = p18b.circle('c4perp', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18b['LussoOther'] = p18b.circle('c4perp', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c18b['SDSSRM'] = p18b.circle('c4perp', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c18b['HST'] = p18b.circle('c4perp', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c18b['Nardini'] = p18b.circle('c4perp', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c18b['Good'] = p18b.circle('c4perp', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p18b.yaxis.axis_label = 'Blueshift'
p18b.xaxis.axis_label = 'CIV Perp Dist'
#p5.x_range.flipped = True
p18b.legend.click_policy="hide"
p18b.legend.glyph_height = gheight
p18b.legend.spacing = lspace
p18b.legend.label_text_font = lfont
p18b.legend.label_text_font_size = lsize
p18b.legend.label_height = lheight
p18b.legend.label_width = lwidth
p18b.legend.margin = lmargin
p18b.legend.location = 'top_left'
c18b['TimlinClean'].visible = visTimlinClean
c18b['TimlinOther'].visible = visTimlinOther
c18b['LussoClean'].visible = visLussoClean
c18b['LussoOther'].visible = visLussoOther
c18b['SDSSRM'].visible = visSDSSRM
c18b['HST'].visible = visHST
c18b['Nardini'].visible = visNardini


c19 = {}
p19 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c19['TimlinClean'] = p19.circle('logEdd', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c19['TimlinOther'] = p19.circle('logEdd', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c19['LussoClean'] = p19.circle('logEdd', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c19['LussoOther'] = p19.circle('logEdd', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c19['SDSSRM'] = p19.circle('logEdd', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c19['HST'] = p19.circle('logEdd', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c19['Nardini'] = p19.circle('logEdd', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c19['Good'] = p19.circle('logEdd', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p19.yaxis.axis_label = 'Blueshift'
p19.xaxis.axis_label = 'logEdd'
#p5.x_range.flipped = True
p19.legend.click_policy="hide"
p19.legend.glyph_height = gheight
p19.legend.spacing = lspace
p19.legend.label_text_font = lfont
p19.legend.label_text_font_size = lsize
p19.legend.label_height = lheight
p19.legend.label_width = lwidth
p19.legend.margin = lmargin
p19.legend.location = 'top_left'
c19['TimlinClean'].visible = visTimlinClean
c19['TimlinOther'].visible = visTimlinOther
c19['LussoClean'].visible = visLussoClean
c19['LussoOther'].visible = visLussoOther
c19['SDSSRM'].visible = visSDSSRM
c19['HST'].visible = visHST
c19['Nardini'].visible = visNardini

c20 = {}
p20 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(7, 11))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c20['TimlinClean'] = p20.circle('logBHM', 'c4blue', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c20['TimlinOther'] = p20.circle('logBHM', 'c4blue', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c20['LussoClean'] = p20.circle('logBHM', 'c4blue', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c20['LussoOther'] = p20.circle('logBHM', 'c4blue', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c20['SDSSRM'] = p20.circle('logBHM', 'c4blue', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c20['HST'] = p20.circle('logBHM', 'c4blue', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c20['Nardini'] = p20.circle('logBHM', 'c4blue', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c20['Good'] = p20.circle('logBHM', 'c4blue', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p20.yaxis.axis_label = 'Blueshift'
p20.xaxis.axis_label = 'logBHM'
#p5.x_range.flipped = True
p20.legend.click_policy="hide"
p20.legend.glyph_height = gheight
p20.legend.spacing = lspace
p20.legend.label_text_font = lfont
p20.legend.label_text_font_size = lsize
p20.legend.label_height = lheight
p20.legend.label_width = lwidth
p20.legend.margin = lmargin
p20.legend.location = 'top_left'
c20['TimlinClean'].visible = visTimlinClean
c20['TimlinOther'].visible = visTimlinOther
c20['LussoClean'].visible = visLussoClean
c20['LussoOther'].visible = visLussoOther
c20['SDSSRM'].visible = visSDSSRM
c20['HST'].visible = visHST
c20['Nardini'].visible = visNardini


# put all the plots in a gridplot
p = gridplot([[p11, p12, p13], [p14, p15, p16], [p17, p18, p18b],  [p19, p20, ]], sizing_mode='scale_width')

tab2 = Panel(child = p, title = 'CIV Blueshift')

# %%
#L2500 Panel

c21 = {}
# create a new plot
p21 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, y_range=(-1500,6500))
c21['TimlinClean'] = p21.circle('c4dist', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c21['TimlinOther'] = p21.circle('c4dist', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c21['LussoClean'] = p21.circle('c4dist', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c21['LussoOther'] = p21.circle('c4dist', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c21['SDSSRM'] = p21.circle('c4dist', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c21['HST'] = p21.circle('c4dist', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c21['Nardini'] = p21.circle('c4dist', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c21['Good'] = p21.circle('c4dist', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p21.yaxis.axis_label = 'logL2500'
p21.xaxis.axis_label = 'CIV Distance'
p21.legend.click_policy="hide"
p21.legend.glyph_height = gheight
p21.legend.spacing = lspace
p21.legend.label_text_font = lfont
p21.legend.label_text_font_size = lsize
p21.legend.label_height = lheight
p21.legend.label_width = lwidth
p21.legend.margin = lmargin
p21.legend.location = 'top_left'
c21['TimlinClean'].visible = visTimlinClean
c21['TimlinOther'].visible = visTimlinOther
c21['LussoClean'].visible = visLussoClean
c21['LussoOther'].visible = visLussoOther
c21['SDSSRM'].visible = visSDSSRM
c21['HST'].visible = visHST
c21['Nardini'].visible = visNardini

c22 = {}
p22 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, y_range=(-1500,6500))
c22['TimlinClean'] = p22.circle('logc4ew', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c22['TimlinOther'] = p22.circle('logc4ew', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c22['LussoClean'] = p22.circle('logc4ew', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c22['LussoOther'] = p22.circle('logc4ew', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c22['SDSSRM'] = p22.circle('logc4ew', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c22['HST'] = p22.circle('logc4ew', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c22['Nardini'] = p22.circle('logc4ew', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c22['Good'] = p22.circle('logc4ew', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p22.yaxis.axis_label = 'logL2500'
p22.xaxis.axis_label = 'log(CIV EW)'
p22.legend.click_policy="hide"
p22.legend.glyph_height = gheight
p22.legend.spacing = lspace
p22.legend.label_text_font = lfont
p22.legend.label_text_font_size = lsize
p22.legend.label_height = lheight
p22.legend.label_width = lwidth
p22.legend.margin = lmargin
p22.legend.location = 'top_right'
c22['TimlinClean'].visible = visTimlinClean
c22['TimlinOther'].visible = visTimlinOther
c22['LussoClean'].visible = visLussoClean
c22['LussoOther'].visible = visLussoOther
c22['SDSSRM'].visible = visSDSSRM
c22['HST'].visible = visHST
c22['Nardini'].visible = visNardini

c23 = {}
p23 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, y_range=(-1500,6500))
c23['TimlinClean'] = p23.circle('he2ew', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c23['TimlinOther'] = p23.circle('he2ew', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c23['LussoClean'] = p23.circle('he2ew', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c23['LussoOther'] = p23.circle('he2ew', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c23['SDSSRM'] = p23.circle('he2ew', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c23['HST'] = p23.circle('he2ew', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c23['Nardini'] = p23.circle('he2ew', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c23['Good'] = p23.circle('he2ew', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p23.yaxis.axis_label = 'logL2500'
p23.xaxis.axis_label = 'log(HeII EQW)'
p23.legend.click_policy="hide"
p23.legend.glyph_height = gheight
p23.legend.spacing = lspace
p23.legend.label_text_font = lfont
p23.legend.label_text_font_size = lsize
p23.legend.label_height = lheight
p23.legend.label_width = lwidth
p23.legend.margin = lmargin
p23.legend.location = 'top_right'
c23['TimlinClean'].visible = visTimlinClean
c23['TimlinOther'].visible = visTimlinOther
c23['LussoClean'].visible = visLussoClean
c23['LussoOther'].visible = visLussoOther
c23['SDSSRM'].visible = visSDSSRM
c23['HST'].visible = visHST
c23['Nardini'].visible = visNardini
                           

c24 = {}
p24 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, x_range=(0.5, -0.5), y_range=(-1500,6500))
c24['TimlinClean'] = p24.circle('gamma', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c24['TimlinOther'] = p24.circle('gamma', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c24['LussoClean'] = p24.circle('gamma', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c24['LussoOther'] = p24.circle('gamma', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c24['SDSSRM'] = p24.circle('gamma', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c24['HST'] = p24.circle('gamma', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c24['Nardini'] = p24.circle('gamma', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c24['Good'] = p24.circle('gamma', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p24.yaxis.axis_label = 'logL2500'
p24.xaxis.axis_label = 'Gamma'
#p6.x_range.flipped = True
p24.legend.click_policy="hide"
p24.legend.glyph_height = gheight
p24.legend.spacing = lspace
p24.legend.label_text_font = lfont
p24.legend.label_text_font_size = lsize
p24.legend.label_height = lheight
p24.legend.label_width = lwidth
p24.legend.margin = lmargin
p24.legend.location = 'top_right'
c24['TimlinClean'].visible = visTimlinClean
c24['TimlinOther'].visible = visTimlinOther
c24['LussoClean'].visible = visLussoClean
c24['LussoOther'].visible = visLussoOther
c24['SDSSRM'].visible = visSDSSRM
c24['HST'].visible = visHST
c24['Nardini'].visible = visNardini

c25 = {}
p25 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c25['TimlinClean'] = p25.circle('aox', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c25['TimlinOther'] = p25.circle('aox', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c25['LussoClean'] = p25.circle('aox', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c25['LussoOther'] = p25.circle('aox', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c25['SDSSRM'] = p25.circle('aox', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c25['HST'] = p25.circle('aox', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c25['Nardini'] = p25.circle('aox', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c25['Good'] = p25.circle('aox', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p25.yaxis.axis_label = 'logL2500'
p25.xaxis.axis_label = 'alpha_ox'
#p5.x_range.flipped = True
p25.legend.click_policy="hide"
p25.legend.glyph_height = gheight
p25.legend.spacing = lspace
p25.legend.label_text_font = lfont
p25.legend.label_text_font_size = lsize
p25.legend.label_height = lheight
p25.legend.label_width = lwidth
p25.legend.margin = lmargin
p25.legend.location = 'top_right'
c25['TimlinClean'].visible = visTimlinClean
c25['TimlinOther'].visible = visTimlinOther
c25['LussoClean'].visible = visLussoClean
c25['LussoOther'].visible = visLussoOther
c25['SDSSRM'].visible = visSDSSRM
c25['HST'].visible = visHST
c25['Nardini'].visible = visNardini

c26 = {}
p26 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c26['TimlinClean'] = p26.circle('ndaox', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c26['TimlinOther'] = p26.circle('ndaox', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c26['LussoClean'] = p26.circle('ndaox', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c26['LussoOther'] = p26.circle('ndaox', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c26['SDSSRM'] = p26.circle('ndaox', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c26['HST'] = p26.circle('ndaox', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c26['Nardini'] = p26.circle('ndaox', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c26['Good'] = p26.circle('ndaox', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p26.yaxis.axis_label = 'logL2500'
p26.xaxis.axis_label = 'delta_aox'
#p5.x_range.flipped = True
p26.legend.click_policy="hide"
p26.legend.glyph_height = gheight
p26.legend.spacing = lspace
p26.legend.label_text_font = lfont
p26.legend.label_text_font_size = lsize
p26.legend.label_height = lheight
p26.legend.label_width = lwidth
p26.legend.margin = lmargin
p26.legend.location = 'top_right'
c26['TimlinClean'].visible = visTimlinClean
c26['TimlinOther'].visible = visTimlinOther
c26['LussoClean'].visible = visLussoClean
c26['LussoOther'].visible = visLussoOther
c26['SDSSRM'].visible = visSDSSRM
c26['HST'].visible = visHST
c26['Nardini'].visible = visNardini


c27 = {}
p27 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c27['TimlinClean'] = p27.circle('c4blue', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c27['TimlinOther'] = p27.circle('c4blue', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c27['LussoClean'] = p27.circle('c4blue', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c27['LussoOther'] = p27.circle('c4blue', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c27['SDSSRM'] = p27.circle('c4blue', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c27['HST'] = p27.circle('c4blue', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c27['Nardini'] = p27.circle('c4blue', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c27['Good'] = p27.circle('c4blue', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p27.yaxis.axis_label = 'logL2500'
p27.xaxis.axis_label = 'Blueshift'
#p5.x_range.flipped = True
p27.legend.click_policy="hide"
p27.legend.glyph_height = gheight
p27.legend.spacing = lspace
p27.legend.label_text_font = lfont
p27.legend.label_text_font_size = lsize
p27.legend.label_height = lheight
p27.legend.label_width = lwidth
p27.legend.margin = lmargin
p27.legend.location = 'top_left'
c27['TimlinClean'].visible = visTimlinClean
c27['TimlinOther'].visible = visTimlinOther
c27['LussoClean'].visible = visLussoClean
c27['LussoOther'].visible = visLussoOther
c27['SDSSRM'].visible = visSDSSRM
c27['HST'].visible = visHST
c27['Nardini'].visible = visNardini

c28 = {}
p28 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(-35, -29), y_range=(29.3, 32.6))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c28['TimlinClean'] = p28.circle('f2keV', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28['TimlinOther'] = p28.circle('f2keV', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28['LussoClean'] = p28.circle('f2keV', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28['LussoOther'] = p28.circle('f2keV', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28['SDSSRM'] = p28.circle('f2keV', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c28['HST'] = p28.circle('f2keV', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c28['Nardini'] = p28.circle('f2keV', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c28['Good'] = p28.circle('f2keV', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p28.yaxis.axis_label = 'logL2500'
p28.xaxis.axis_label = 'log f 2keV'
#p5.x_range.flipped = True
p28.legend.click_policy="hide"
p28.legend.glyph_height = gheight
p28.legend.spacing = lspace
p28.legend.label_text_font = lfont
p28.legend.label_text_font_size = lsize
p28.legend.label_height = lheight
p28.legend.label_width = lwidth
p28.legend.margin = lmargin
p28.legend.location = 'top_left'
c28['TimlinClean'].visible = visTimlinClean
c28['TimlinOther'].visible = visTimlinOther
c28['LussoClean'].visible = visLussoClean
c28['LussoOther'].visible = visLussoOther
c28['SDSSRM'].visible = visSDSSRM
c28['HST'].visible = visHST
c28['Nardini'].visible = visNardini

c28b = {}
p28b = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(29.3, 32.6))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c28b['TimlinClean'] = p28b.circle('c4perp', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28b['TimlinOther'] = p28b.circle('c4perp', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28b['LussoClean'] = p28b.circle('c4perp', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28b['LussoOther'] = p28b.circle('c4perp', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c28b['SDSSRM'] = p28b.circle('c4perp', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c28b['HST'] = p28b.circle('c4perp', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c28b['Nardini'] = p28b.circle('c4perp', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c28b['Good'] = p28b.circle('c4perp', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p28b.yaxis.axis_label = 'logL2500'
p28b.xaxis.axis_label = 'CIV Perp Dist'
#p5.x_range.flipped = True
p28b.legend.click_policy="hide"
p28b.legend.glyph_height = gheight
p28b.legend.spacing = lspace
p28b.legend.label_text_font = lfont
p28b.legend.label_text_font_size = lsize
p28b.legend.label_height = lheight
p28b.legend.label_width = lwidth
p28b.legend.margin = lmargin
p28b.legend.location = 'top_left'
c28b['TimlinClean'].visible = visTimlinClean
c28b['TimlinOther'].visible = visTimlinOther
c28b['LussoClean'].visible = visLussoClean
c28b['LussoOther'].visible = visLussoOther
c28b['SDSSRM'].visible = visSDSSRM
c28b['HST'].visible = visHST
c28b['Nardini'].visible = visNardini


c29 = {}
p29 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c29['TimlinClean'] = p29.circle('logEdd', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c29['TimlinOther'] = p29.circle('logEdd', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c29['LussoClean'] = p29.circle('logEdd', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c29['LussoOther'] = p29.circle('logEdd', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c29['SDSSRM'] = p29.circle('logEdd', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c29['HST'] = p29.circle('logEdd', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c29['Nardini'] = p29.circle('logEdd', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c29['Good'] = p29.circle('logEdd', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p29.yaxis.axis_label = 'logL2500'
p29.xaxis.axis_label = 'logEdd'
#p5.x_range.flipped = True
p29.legend.click_policy="hide"
p29.legend.glyph_height = gheight
p29.legend.spacing = lspace
p29.legend.label_text_font = lfont
p29.legend.label_text_font_size = lsize
p29.legend.label_height = lheight
p29.legend.label_width = lwidth
p29.legend.margin = lmargin
p29.legend.location = 'top_left'
c29['TimlinClean'].visible = visTimlinClean
c29['TimlinOther'].visible = visTimlinOther
c29['LussoClean'].visible = visLussoClean
c29['LussoOther'].visible = visLussoOther
c29['SDSSRM'].visible = visSDSSRM
c29['HST'].visible = visHST
c29['Nardini'].visible = visNardini

c30 = {}
p30 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(7, 11))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c30['TimlinClean'] = p30.circle('logBHM', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c30['TimlinOther'] = p30.circle('logBHM', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c30['LussoClean'] = p30.circle('logBHM', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c30['LussoOther'] = p30.circle('logBHM', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c30['SDSSRM'] = p30.circle('logBHM', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c30['HST'] = p30.circle('logBHM', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c30['Nardini'] = p30.circle('logBHM', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c30['Good'] = p30.circle('logBHM', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p30.yaxis.axis_label = 'logL2500'
p30.xaxis.axis_label = 'logBHM'
#p5.x_range.flipped = True
p30.legend.click_policy="hide"
p30.legend.glyph_height = gheight
p30.legend.spacing = lspace
p30.legend.label_text_font = lfont
p30.legend.label_text_font_size = lsize
p30.legend.label_height = lheight
p30.legend.label_width = lwidth
p30.legend.margin = lmargin
p30.legend.location = 'top_left'
c30['TimlinClean'].visible = visTimlinClean
c30['TimlinOther'].visible = visTimlinOther
c30['LussoClean'].visible = visLussoClean
c30['LussoOther'].visible = visLussoOther
c30['SDSSRM'].visible = visSDSSRM
c30['HST'].visible = visHST
c30['Nardini'].visible = visNardini


# put all the plots in a gridplot
p = gridplot([[p21, p22, p23], [p24, p25, p26], [p27, p28, p28b],  [p29, p30, ]], sizing_mode='scale_width')

tab3 = Panel(child = p, title = 'L2500')

# %%
#MISC

c31 = {}
p31 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c31['TimlinClean'] = p31.circle('z', 'logL2500', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c31['TimlinOther'] = p31.circle('z', 'logL2500', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c31['LussoClean'] = p31.circle('z', 'logL2500', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c31['LussoOther'] = p31.circle('z', 'logL2500', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c31['SDSSRM'] = p31.circle('z', 'logL2500', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c31['HST'] = p31.circle('z', 'logL2500', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c31['Nardini'] = p31.circle('z', 'logL2500', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c31['Good'] = p31.circle('z', 'logL2500', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p31.yaxis.axis_label = 'log L2500'
p31.xaxis.axis_label = 'Redshift'
p31.legend.click_policy="hide"
p31.legend.glyph_height = gheight
p31.legend.spacing = lspace
p31.legend.label_text_font = lfont
p31.legend.label_text_font_size = lsize
p31.legend.label_height = lheight
p31.legend.label_width = lwidth
p31.legend.margin = lmargin
p31.legend.location = 'top_left'
c31['TimlinClean'].visible = visTimlinClean
c31['TimlinOther'].visible = visTimlinOther
c31['LussoClean'].visible = visLussoClean
c31['LussoOther'].visible = visLussoOther
c31['SDSSRM'].visible = visSDSSRM
c31['HST'].visible = visHST
c31['Nardini'].visible = visNardini

c32 = {}
p32 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c32['TimlinClean'] = p32.circle('z', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c32['TimlinOther'] = p32.circle('z', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c32['LussoClean'] = p32.circle('z', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c32['LussoOther'] = p32.circle('z', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c32['SDSSRM'] = p32.circle('z', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c32['HST'] = p32.circle('z', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c32['Nardini'] = p32.circle('z', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c32['Good'] = p32.circle('z', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p32.yaxis.axis_label = 'Delta (g-i)'
p32.xaxis.axis_label = 'Redshift'
p32.legend.click_policy="hide"
p32.legend.glyph_height = gheight
p32.legend.spacing = lspace
p32.legend.label_text_font = lfont
p32.legend.label_text_font_size = lsize
p32.legend.label_height = lheight
p32.legend.label_width = lwidth
p32.legend.margin = lmargin
p32.legend.location = 'top_left'
c32['TimlinClean'].visible = visTimlinClean
c32['TimlinOther'].visible = visTimlinOther
c32['LussoClean'].visible = visLussoClean
c32['LussoOther'].visible = visLussoOther
c32['SDSSRM'].visible = visSDSSRM
c32['HST'].visible = visHST
c32['Nardini'].visible = visNardini

c33 = {}
p33 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c33['TimlinClean'] = p33.circle('ndaox', 'gamma', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c33['TimlinOther'] = p33.circle('ndaox', 'gamma', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c33['LussoClean'] = p33.circle('ndaox', 'gamma', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c33['LussoOther'] = p33.circle('ndaox', 'gamma', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c33['SDSSRM'] = p33.circle('ndaox', 'gamma', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c33['HST'] = p33.circle('ndaox', 'gamma', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c33['Nardini'] = p33.circle('ndaox', 'gamma', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c33['Good'] = p33.circle('ndaox', 'gamma', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p33.yaxis.axis_label = 'Gamma'
p33.xaxis.axis_label = 'delta_aox'
#p5.x_range.flipped = True
p33.legend.click_policy="hide"
p33.legend.glyph_height = gheight
p33.legend.spacing = lspace
p33.legend.label_text_font = lfont
p33.legend.label_text_font_size = lsize
p33.legend.label_height = lheight
p33.legend.label_width = lwidth
p33.legend.margin = lmargin
p33.legend.location = 'top_left'
c33['TimlinClean'].visible = visTimlinClean
c33['TimlinOther'].visible = visTimlinOther
c33['LussoClean'].visible = visLussoClean
c33['LussoOther'].visible = visLussoOther
c33['SDSSRM'].visible = visSDSSRM
c33['HST'].visible = visHST
c33['Nardini'].visible = visNardini


c34 = {}
p34 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c34['TimlinClean'] = p34.circle('he2ew', 'logc4ew', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c34['TimlinOther'] = p34.circle('he2ew', 'logc4ew', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c34['LussoClean'] = p34.circle('he2ew', 'logc4ew', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c34['LussoOther'] = p34.circle('he2ew', 'logc4ew', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c34['SDSSRM'] = p34.circle('he2ew', 'logc4ew', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c34['HST'] = p34.circle('he2ew', 'logc4ew', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c34['Nardini'] = p34.circle('he2ew', 'logc4ew', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c34['Good'] = p34.circle('he2ew', 'logc4ew', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p34.yaxis.axis_label = 'log(CIV EW)'
p34.xaxis.axis_label = 'log(HeII EQW)'
p34.legend.click_policy="hide"
p34.legend.glyph_height = gheight
p34.legend.spacing = lspace
p34.legend.label_text_font = lfont
p34.legend.label_text_font_size = lsize
p34.legend.label_height = lheight
p34.legend.label_width = lwidth
p34.legend.margin = lmargin
p34.legend.location = 'top_left'
c34['TimlinClean'].visible = visTimlinClean
c34['TimlinOther'].visible = visTimlinOther
c34['LussoClean'].visible = visLussoClean
c34['LussoOther'].visible = visLussoOther
c34['SDSSRM'].visible = visSDSSRM
c34['HST'].visible = visHST
c34['Nardini'].visible = visNardini

c35 = {}
p35 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c35['TimlinClean'] = p35.circle('he2ew', 'aox', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c35['TimlinOther'] = p35.circle('he2ew', 'aox', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c35['LussoClean'] = p35.circle('he2ew', 'aox', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c35['LussoOther'] = p35.circle('he2ew', 'aox', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c35['SDSSRM'] = p35.circle('he2ew', 'aox', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c35['HST'] = p35.circle('he2ew', 'aox', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c35['Nardini'] = p35.circle('he2ew', 'aox', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c35['Good'] = p35.circle('he2ew', 'aox', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p35.yaxis.axis_label = 'alpha_ox'
p35.xaxis.axis_label = 'log(HeII EQW)'
p35.legend.click_policy="hide"
p35.legend.glyph_height = gheight
p35.legend.spacing = lspace
p35.legend.label_text_font = lfont
p35.legend.label_text_font_size = lsize
p35.legend.label_height = lheight
p35.legend.label_width = lwidth
p35.legend.margin = lmargin
p35.legend.location = 'top_left'
c35['TimlinClean'].visible = visTimlinClean
c35['TimlinOther'].visible = visTimlinOther
c35['LussoClean'].visible = visLussoClean
c35['LussoOther'].visible = visLussoOther
c35['SDSSRM'].visible = visSDSSRM
c35['HST'].visible = visHST
c35['Nardini'].visible = visNardini

c36 = {}
p36 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c36['TimlinClean'] = p36.circle('c4perp', 'aox', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c36['TimlinOther'] = p36.circle('c4perp', 'aox', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c36['LussoClean'] = p36.circle('c4perp', 'aox', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c36['LussoOther'] = p36.circle('c4perp', 'aox', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c36['SDSSRM'] = p36.circle('c4perp', 'aox', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c36['HST'] = p36.circle('c4perp', 'aox', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c36['Nardini'] = p36.circle('c4perp', 'aox', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c36['Good'] = p36.circle('c4perp', 'aox', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p36.yaxis.axis_label = 'alpha_ox'
p36.xaxis.axis_label = 'CIV Perp Dist'
p36.legend.click_policy="hide"
p36.legend.glyph_height = gheight
p36.legend.spacing = lspace
p36.legend.label_text_font = lfont
p36.legend.label_text_font_size = lsize
p36.legend.label_height = lheight
p36.legend.label_width = lwidth
p36.legend.margin = lmargin
p36.legend.location = 'top_left'
c36['TimlinClean'].visible = visTimlinClean
c36['TimlinOther'].visible = visTimlinOther
c36['LussoClean'].visible = visLussoClean
c36['LussoOther'].visible = visLussoOther
c36['SDSSRM'].visible = visSDSSRM
c36['HST'].visible = visHST
c36['Nardini'].visible = visNardini

c37 = {}
p37 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c37['TimlinClean'] = p37.circle('logL2500', 'aox', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c37['TimlinOther'] = p37.circle('logL2500', 'aox', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c37['LussoClean'] = p37.circle('logL2500', 'aox', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c37['LussoOther'] = p37.circle('logL2500', 'aox', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c37['SDSSRM'] = p37.circle('logL2500', 'aox', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c37['HST'] = p37.circle('logL2500', 'aox', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c37['Nardini'] = p37.circle('logL2500', 'aox', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c37['Good'] = p37.circle('logL2500', 'aox', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")

p37.line(X_new[:,0], y_pred2, color='red', legend_label="Predictions")
p37.line(X_new[:,0], y_pred3[:,0], color='green', legend_label="Rivera")
p37.line(y_pred4, X_new2[:,0], color='black', legend_label="Inverse")

p37.xaxis.axis_label = 'logL2500'
p37.yaxis.axis_label = 'alpha_ox'
#p5.x_range.flipped = True
p37.legend.click_policy="hide"
p37.legend.glyph_height = gheight
p37.legend.spacing = lspace
p37.legend.label_text_font = lfont
p37.legend.label_text_font_size = lsize
p37.legend.label_height = lheight
p37.legend.label_width = lwidth
p37.legend.margin = lmargin
p37.legend.location = 'top_right'
c37['TimlinClean'].visible = visTimlinClean
c37['TimlinOther'].visible = visTimlinOther
c37['LussoClean'].visible = visLussoClean
c37['LussoOther'].visible = visLussoOther
c37['SDSSRM'].visible = visSDSSRM
c37['HST'].visible = visHST
c37['Nardini'].visible = visNardini



c38 = {}
p38 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c38['TimlinClean'] = p38.circle('logc4ew', 'aox', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c38['TimlinOther'] = p38.circle('logc4ew', 'aox', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c38['LussoClean'] = p38.circle('logc4ew', 'aox', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c38['LussoOther'] = p38.circle('logc4ew', 'aox', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c38['SDSSRM'] = p38.circle('logc4ew', 'aox', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c38['HST'] = p38.circle('logc4ew', 'aox', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c38['Nardini'] = p38.circle('logc4ew', 'aox', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c38['Good'] = p38.circle('logc4ew', 'aox', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p38.xaxis.axis_label = 'CIV EW'
p38.yaxis.axis_label = 'alpha_ox'
#p5.x_range.flipped = True
p38.legend.click_policy="hide"
p38.legend.glyph_height = gheight
p38.legend.spacing = lspace
p38.legend.label_text_font = lfont
p38.legend.label_text_font_size = lsize
p38.legend.label_height = lheight
p38.legend.label_width = lwidth
p38.legend.margin = lmargin
p38.legend.location = 'top_right'
c38['TimlinClean'].visible = visTimlinClean
c38['TimlinOther'].visible = visTimlinOther
c38['LussoClean'].visible = visLussoClean
c38['LussoOther'].visible = visLussoOther
c38['SDSSRM'].visible = visSDSSRM
c38['HST'].visible = visHST
c38['Nardini'].visible = visNardini

c39 = {}
p39 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c39['TimlinClean'] = p39.circle('c4perp', 'ndaox', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c39['TimlinOther'] = p39.circle('c4perp', 'ndaox', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c39['LussoClean'] = p39.circle('c4perp', 'ndaox', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c39['LussoOther'] = p39.circle('c4perp', 'ndaox', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c39['SDSSRM'] = p39.circle('c4perp', 'ndaox', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c39['HST'] = p39.circle('c4perp', 'ndaox', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c39['Nardini'] = p39.circle('c4perp', 'ndaox', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c39['Good'] = p39.circle('c4perp', 'ndaox', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p39.yaxis.axis_label = 'Delta_alpha_ox'
p39.xaxis.axis_label = 'CIV Perp Dist'
p39.legend.click_policy="hide"
p39.legend.glyph_height = gheight
p39.legend.spacing = lspace
p39.legend.label_text_font = lfont
p39.legend.label_text_font_size = lsize
p39.legend.label_height = lheight
p39.legend.label_width = lwidth
p39.legend.margin = lmargin
p39.legend.location = 'top_left'
c39['TimlinClean'].visible = visTimlinClean
c39['TimlinOther'].visible = visTimlinOther
c39['LussoClean'].visible = visLussoClean
c39['LussoOther'].visible = visLussoOther
c39['SDSSRM'].visible = visSDSSRM
c39['HST'].visible = visHST
c39['Nardini'].visible = visNardini


c40 = {}
p40 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.5))#, y_range=(-1500,6500))
c40['TimlinClean'] = p40.circle('c4dist', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c40['TimlinOther'] = p40.circle('c4dist', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c40['LussoClean'] = p40.circle('c4dist', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c40['LussoOther'] = p40.circle('c4dist', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c40['SDSSRM'] = p40.circle('c4dist', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c40['HST'] = p40.circle('c4dist', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c40['Nardini'] = p40.circle('c4dist', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c40['Good'] = p40.circle('c4dist', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p40.yaxis.axis_label = 'Delta (g-i)'
p40.xaxis.axis_label = 'CIV Distance'
p40.legend.click_policy="hide"
p40.legend.glyph_height = gheight
p40.legend.spacing = lspace
p40.legend.label_text_font = lfont
p40.legend.label_text_font_size = lsize
p40.legend.label_height = lheight
p40.legend.label_width = lwidth
p40.legend.margin = lmargin
p40.legend.location = 'top_left'
c40['TimlinClean'].visible = visTimlinClean
c40['TimlinOther'].visible = visTimlinOther
c40['LussoClean'].visible = visLussoClean
c40['LussoOther'].visible = visLussoOther
c40['SDSSRM'].visible = visSDSSRM
c40['HST'].visible = visHST
c40['Nardini'].visible = visNardini

c41 = {}
p41 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.5))#, y_range=(-1500,6500))
c41['TimlinClean'] = p41.circle('c4perp', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c41['TimlinOther'] = p41.circle('c4perp', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c41['LussoClean'] = p41.circle('c4perp', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c41['LussoOther'] = p41.circle('c4perp', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c41['SDSSRM'] = p41.circle('c4perp', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c41['HST'] = p41.circle('c4perp', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c41['Nardini'] = p41.circle('c4perp', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c41['Good'] = p41.circle('c4perp', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p41.yaxis.axis_label = 'Delta (g-i)'
p41.xaxis.axis_label = 'CIV Perp Dist'
p41.legend.click_policy="hide"
p41.legend.glyph_height = gheight
p41.legend.spacing = lspace
p41.legend.label_text_font = lfont
p41.legend.label_text_font_size = lsize
p41.legend.label_height = lheight
p41.legend.label_width = lwidth
p41.legend.margin = lmargin
p41.legend.location = 'top_left'
c41['TimlinClean'].visible = visTimlinClean
c41['TimlinOther'].visible = visTimlinOther
c41['LussoClean'].visible = visLussoClean
c41['LussoOther'].visible = visLussoOther
c41['SDSSRM'].visible = visSDSSRM
c41['HST'].visible = visHST
c41['Nardini'].visible = visNardini


# put all the plots in a gridplot
p = gridplot([[p31, p32, p34], [p33, p35, p36], [p37, p38, p39] ], sizing_mode='scale_width')

tab4 = Panel(child = p, title = 'MISC')

# %%
#CIV Perp Dist Panel

c51 = {}
# create a new plot
p51 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c51['TimlinClean'] = p51.circle('c4blue', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c51['TimlinOther'] = p51.circle('c4blue', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c51['LussoClean'] = p51.circle('c4blue', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c51['LussoOther'] = p51.circle('c4blue', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c51['SDSSRM'] = p51.circle('c4blue', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c51['HST'] = p51.circle('c4blue', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c51['Nardini'] = p51.circle('c4blue', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c51['Good'] = p51.circle('c4blue', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p51.yaxis.axis_label = 'CIV Perp Dist'
p51.xaxis.axis_label = 'Blueshift'
p51.legend.click_policy="hide"
p51.legend.glyph_height = gheight
p51.legend.spacing = lspace
p51.legend.label_text_font = lfont
p51.legend.label_text_font_size = lsize
p51.legend.label_height = lheight
p51.legend.label_width = lwidth
p51.legend.margin = lmargin
p51.legend.location = 'top_left'
c51['TimlinClean'].visible = visTimlinClean
c51['TimlinOther'].visible = visTimlinOther
c51['LussoClean'].visible = visLussoClean
c51['LussoOther'].visible = visLussoOther
c51['SDSSRM'].visible = visSDSSRM
c51['HST'].visible = visHST
c51['Nardini'].visible = visNardini

c52 = {}
p52 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c52['TimlinClean'] = p52.circle('logc4ew', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c52['TimlinOther'] = p52.circle('logc4ew', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c52['LussoClean'] = p52.circle('logc4ew', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c52['LussoOther'] = p52.circle('logc4ew', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c52['SDSSRM'] = p52.circle('logc4ew', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c52['HST'] = p52.circle('logc4ew', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c52['Nardini'] = p52.circle('logc4ew', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c52['Good'] = p52.circle('logc4ew', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p52.yaxis.axis_label = 'CIV Perp Dist'
p52.xaxis.axis_label = 'log(CIV EW)'
p52.legend.click_policy="hide"
p52.legend.glyph_height = gheight
p52.legend.spacing = lspace
p52.legend.label_text_font = lfont
p52.legend.label_text_font_size = lsize
p52.legend.label_height = lheight
p52.legend.label_width = lwidth
p52.legend.margin = lmargin
p52.legend.location = 'top_right'
c52['TimlinClean'].visible = visTimlinClean
c52['TimlinOther'].visible = visTimlinOther
c52['LussoClean'].visible = visLussoClean
c52['LussoOther'].visible = visLussoOther
c52['SDSSRM'].visible = visSDSSRM
c52['HST'].visible = visHST
c52['Nardini'].visible = visNardini

c53 = {}
p53 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, y_range=(-1500,6500))
c53['TimlinClean'] = p53.circle('he2ew', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c53['TimlinOther'] = p53.circle('he2ew', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c53['LussoClean'] = p53.circle('he2ew', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c53['LussoOther'] = p53.circle('he2ew', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c53['SDSSRM'] = p53.circle('he2ew', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c53['HST'] = p53.circle('he2ew', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c53['Nardini'] = p53.circle('he2ew', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c53['Good'] = p53.circle('he2ew', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p53.yaxis.axis_label = 'CIV Perp Dist'
p53.xaxis.axis_label = 'log(HeII EQW)'
p53.legend.click_policy="hide"
p53.legend.glyph_height = gheight
p53.legend.spacing = lspace
p53.legend.label_text_font = lfont
p53.legend.label_text_font_size = lsize
p53.legend.label_height = lheight
p53.legend.label_width = lwidth
p53.legend.margin = lmargin
p53.legend.location = 'top_right'
c53['TimlinClean'].visible = visTimlinClean
c53['TimlinOther'].visible = visTimlinOther
c53['LussoClean'].visible = visLussoClean
c53['LussoOther'].visible = visLussoOther
c53['SDSSRM'].visible = visSDSSRM
c53['HST'].visible = visHST
c53['Nardini'].visible = visNardini

#selection_glyph = Circle(fill_color='orange', line_color=None)
#nonselection_glyph = Circle(fill_color='#1f77b4', fill_alpha=0.1, line_color=None)
#r1.selection_glyph = selection_glyph
#r1.nonselection_glyph = nonselection_glyph

c54 = {}
p54 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.5), y_range=(-1500,6500))
c54['TimlinClean'] = p54.circle('gamma', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c54['TimlinOther'] = p54.circle('gamma', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c54['LussoClean'] = p54.circle('gamma', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c54['LussoOther'] = p54.circle('gamma', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c54['SDSSRM'] = p54.circle('gamma', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c54['HST'] = p54.circle('gamma', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c54['Nardini'] = p54.circle('gamma', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c54['Good'] = p54.circle('gamma', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p54.yaxis.axis_label = 'CIV Perp Dist'
p54.xaxis.axis_label = 'Gamma'
#p56.x_range.flipped = True
p54.legend.click_policy="hide"
p54.legend.glyph_height = gheight
p54.legend.spacing = lspace
p54.legend.label_text_font = lfont
p54.legend.label_text_font_size = lsize
p54.legend.label_height = lheight
p54.legend.label_width = lwidth
p54.legend.margin = lmargin
p54.legend.location = 'top_right'
c54['TimlinClean'].visible = visTimlinClean
c54['TimlinOther'].visible = visTimlinOther
c54['LussoClean'].visible = visLussoClean
c54['LussoOther'].visible = visLussoOther
c54['SDSSRM'].visible = visSDSSRM
c54['HST'].visible = visHST
c54['Nardini'].visible = visNardini

c55 = {}
p55 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c55['TimlinClean'] = p55.circle('aox', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c55['TimlinOther'] = p55.circle('aox', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c55['LussoClean'] = p55.circle('aox', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c55['LussoOther'] = p55.circle('aox', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c55['SDSSRM'] = p55.circle('aox', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c55['HST'] = p55.circle('aox', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c55['Nardini'] = p55.circle('aox', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c55['Good'] = p55.circle('aox', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p55.yaxis.axis_label = 'CIV Perp Dist'
p55.xaxis.axis_label = 'alpha_ox'
#p55.x_range.flipped = True
p55.legend.click_policy="hide"
p55.legend.glyph_height = gheight
p55.legend.spacing = lspace
p55.legend.label_text_font = lfont
p55.legend.label_text_font_size = lsize
p55.legend.label_height = lheight
p55.legend.label_width = lwidth
p55.legend.margin = lmargin
p55.legend.location = 'top_right'
c55['TimlinClean'].visible = visTimlinClean
c55['TimlinOther'].visible = visTimlinOther
c55['LussoClean'].visible = visLussoClean
c55['LussoOther'].visible = visLussoOther
c55['SDSSRM'].visible = visSDSSRM
c55['HST'].visible = visHST
c55['Nardini'].visible = visNardini

c56 = {}
p56 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c56['TimlinClean'] = p56.circle('ndaox', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c56['TimlinOther'] = p56.circle('ndaox', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c56['LussoClean'] = p56.circle('ndaox', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c56['LussoOther'] = p56.circle('ndaox', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c56['SDSSRM'] = p56.circle('ndaox', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c56['HST'] = p56.circle('ndaox', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c56['Nardini'] = p56.circle('ndaox', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c56['Good'] = p56.circle('ndaox', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p56.yaxis.axis_label = 'CIV Perp Dist'
p56.xaxis.axis_label = 'delta_aox'
#p55.x_range.flipped = True
p56.legend.click_policy="hide"
p56.legend.glyph_height = gheight
p56.legend.spacing = lspace
p56.legend.label_text_font = lfont
p56.legend.label_text_font_size = lsize
p56.legend.label_height = lheight
p56.legend.label_width = lwidth
p56.legend.margin = lmargin
p56.legend.location = 'top_right'
c56['TimlinClean'].visible = visTimlinClean
c56['TimlinOther'].visible = visTimlinOther
c56['LussoClean'].visible = visLussoClean
c56['LussoOther'].visible = visLussoOther
c56['SDSSRM'].visible = visSDSSRM
c56['HST'].visible = visHST
c56['Nardini'].visible = visNardini


c57 = {}
p57 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c57['TimlinClean'] = p57.circle('logL2500', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c57['TimlinOther'] = p57.circle('logL2500', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c57['LussoClean'] = p57.circle('logL2500', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c57['LussoOther'] = p57.circle('logL2500', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c57['SDSSRM'] = p57.circle('logL2500', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c57['HST'] = p57.circle('logL2500', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c57['Nardini'] = p57.circle('logL2500', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c57['Good'] = p57.circle('logL2500', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p57.yaxis.axis_label = 'CIV Perp Dist'
p57.xaxis.axis_label = 'logL2500'
#p55.x_range.flipped = True
p57.legend.click_policy="hide"
p57.legend.glyph_height = gheight
p57.legend.spacing = lspace
p57.legend.label_text_font = lfont
p57.legend.label_text_font_size = lsize
p57.legend.label_height = lheight
p57.legend.label_width = lwidth
p57.legend.margin = lmargin
p57.legend.location = 'top_left'
c57['TimlinClean'].visible = visTimlinClean
c57['TimlinOther'].visible = visTimlinOther
c57['LussoClean'].visible = visLussoClean
c57['LussoOther'].visible = visLussoOther
c57['SDSSRM'].visible = visSDSSRM
c57['HST'].visible = visHST
c57['Nardini'].visible = visNardini

c58 = {}
p58 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(-35, -29))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c58['TimlinClean'] = p58.circle('f2keV', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58['TimlinOther'] = p58.circle('f2keV', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58['LussoClean'] = p58.circle('f2keV', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58['LussoOther'] = p58.circle('f2keV', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58['SDSSRM'] = p58.circle('f2keV', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c58['HST'] = p58.circle('f2keV', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c58['Nardini'] = p58.circle('f2keV', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c58['Good'] = p58.circle('f2keV', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p58.yaxis.axis_label = 'CIV Perp Dist'
p58.xaxis.axis_label = 'log f 2keV'
#p55.x_range.flipped = True
p58.legend.click_policy="hide"
p58.legend.glyph_height = gheight
p58.legend.spacing = lspace
p58.legend.label_text_font = lfont
p58.legend.label_text_font_size = lsize
p58.legend.label_height = lheight
p58.legend.label_width = lwidth
p58.legend.margin = lmargin
p58.legend.location = 'top_left'
c58['TimlinClean'].visible = visTimlinClean
c58['TimlinOther'].visible = visTimlinOther
c58['LussoClean'].visible = visLussoClean
c58['LussoOther'].visible = visLussoOther
c58['SDSSRM'].visible = visSDSSRM
c58['HST'].visible = visHST
c58['Nardini'].visible = visNardini

c58b = {}
p58b = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c58b['TimlinClean'] = p58b.circle('c4dist', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58b['TimlinOther'] = p58b.circle('c4dist', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58b['LussoClean'] = p58b.circle('c4dist', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58b['LussoOther'] = p58b.circle('c4dist', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c58b['SDSSRM'] = p58b.circle('c4dist', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c58b['HST'] = p58b.circle('c4dist', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c58b['Nardini'] = p58b.circle('c4dist', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c58b['Good'] = p58b.circle('c4dist', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p58b.xaxis.axis_label = 'CIV Distance'
p58b.yaxis.axis_label = 'CIV Perp Dist'
#p55.x_range.flipped = True
p58b.legend.click_policy="hide"
p58b.legend.glyph_height = gheight
p58b.legend.spacing = lspace
p58b.legend.label_text_font = lfont
p58b.legend.label_text_font_size = lsize
p58b.legend.label_height = lheight
p58b.legend.label_width = lwidth
p58b.legend.margin = lmargin
p58b.legend.location = 'top_left'
c58b['TimlinClean'].visible = visTimlinClean
c58b['TimlinOther'].visible = visTimlinOther
c58b['LussoClean'].visible = visLussoClean
c58b['LussoOther'].visible = visLussoOther
c58b['SDSSRM'].visible = visSDSSRM
c58b['HST'].visible = visHST
c58b['Nardini'].visible = visNardini


c59 = {}
p59 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS)#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c59['TimlinClean'] = p59.circle('logEdd', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c59['TimlinOther'] = p59.circle('logEdd', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c59['LussoClean'] = p59.circle('logEdd', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c59['LussoOther'] = p59.circle('logEdd', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c59['SDSSRM'] = p59.circle('logEdd', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c59['HST'] = p59.circle('logEdd', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c59['Nardini'] = p59.circle('logEdd', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c59['Good'] = p59.circle('logEdd', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p59.yaxis.axis_label = 'CIV Perp Dist'
p59.xaxis.axis_label = 'logEdd'
#p55.x_range.flipped = True
p59.legend.click_policy="hide"
p59.legend.glyph_height = gheight
p59.legend.spacing = lspace
p59.legend.label_text_font = lfont
p59.legend.label_text_font_size = lsize
p59.legend.label_height = lheight
p59.legend.label_width = lwidth
p59.legend.margin = lmargin
p59.legend.location = 'top_left'
c59['TimlinClean'].visible = visTimlinClean
c59['TimlinOther'].visible = visTimlinOther
c59['LussoClean'].visible = visLussoClean
c59['LussoOther'].visible = visLussoOther
c59['SDSSRM'].visible = visSDSSRM
c59['HST'].visible = visHST
c59['Nardini'].visible = visNardini

c60 = {}
p60 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(7, 11))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c60['TimlinClean'] = p60.circle('logBHM', 'c4perp', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c60['TimlinOther'] = p60.circle('logBHM', 'c4perp', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c60['LussoClean'] = p60.circle('logBHM', 'c4perp', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c60['LussoOther'] = p60.circle('logBHM', 'c4perp', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c60['SDSSRM'] = p60.circle('logBHM', 'c4perp', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c60['HST'] = p60.circle('logBHM', 'c4perp', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c60['Nardini'] = p60.circle('logBHM', 'c4perp', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c60['Good'] = p60.circle('logBHM', 'c4perp', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p60.yaxis.axis_label = 'CIV Perp Dist'
p60.xaxis.axis_label = 'logBHM'
#p55.x_range.flipped = True
p60.legend.click_policy="hide"
p60.legend.glyph_height = gheight
p60.legend.spacing = lspace
p60.legend.label_text_font = lfont
p60.legend.label_text_font_size = lsize
p60.legend.label_height = lheight
p60.legend.label_width = lwidth
p60.legend.margin = lmargin
p60.legend.location = 'top_left'
c60['TimlinClean'].visible = visTimlinClean
c60['TimlinOther'].visible = visTimlinOther
c60['LussoClean'].visible = visLussoClean
c60['LussoOther'].visible = visLussoOther
c60['SDSSRM'].visible = visSDSSRM
c60['HST'].visible = visHST
c60['Nardini'].visible = visNardini


# put all the plots in a gridplot
p = gridplot([[p51, p52, p53], [p54, p55, p56], [p57, p58, p58b],  [p59, p60, ]], sizing_mode='scale_width')

tab5 = Panel(child = p, title = 'CIV Perp Dist')

# %%
#Delta (g-i) Panel

c61 = {}
# create a new plot
p61 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, y_range=(-1500,6500))
c61['TimlinClean'] = p61.circle('c4blue', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c61['TimlinOther'] = p61.circle('c4blue', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c61['LussoClean'] = p61.circle('c4blue', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c61['LussoOther'] = p61.circle('c4blue', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c61['SDSSRM'] = p61.circle('c4blue', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c61['HST'] = p61.circle('c4blue', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c61['Nardini'] = p61.circle('c4blue', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c61['Good'] = p61.circle('c4blue', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p61.yaxis.axis_label = 'Delta (g-i)'
p61.xaxis.axis_label = 'Blueshift'
p61.legend.click_policy="hide"
p61.legend.glyph_height = gheight
p61.legend.spacing = lspace
p61.legend.label_text_font = lfont
p61.legend.label_text_font_size = lsize
p61.legend.label_height = lheight
p61.legend.label_width = lwidth
p61.legend.margin = lmargin
p61.legend.location = 'top_left'
c61['TimlinClean'].visible = visTimlinClean
c61['TimlinOther'].visible = visTimlinOther
c61['LussoClean'].visible = visLussoClean
c61['LussoOther'].visible = visLussoOther
c61['SDSSRM'].visible = visSDSSRM
c61['HST'].visible = visHST
c61['Nardini'].visible = visNardini

c62 = {}
p62 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, y_range=(-1500,6500))
c62['TimlinClean'] = p62.circle('logc4ew', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c62['TimlinOther'] = p62.circle('logc4ew', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c62['LussoClean'] = p62.circle('logc4ew', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c62['LussoOther'] = p62.circle('logc4ew', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c62['SDSSRM'] = p62.circle('logc4ew', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c62['HST'] = p62.circle('logc4ew', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c62['Nardini'] = p62.circle('logc4ew', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c62['Good'] = p62.circle('logc4ew', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p62.yaxis.axis_label = 'Delta (g-i)'
p62.xaxis.axis_label = 'log(CIV EW)'
p62.legend.click_policy="hide"
p62.legend.glyph_height = gheight
p62.legend.spacing = lspace
p62.legend.label_text_font = lfont
p62.legend.label_text_font_size = lsize
p62.legend.label_height = lheight
p62.legend.label_width = lwidth
p62.legend.margin = lmargin
p62.legend.location = 'top_right'
c62['TimlinClean'].visible = visTimlinClean
c62['TimlinOther'].visible = visTimlinOther
c62['LussoClean'].visible = visLussoClean
c62['LussoOther'].visible = visLussoOther
c62['SDSSRM'].visible = visSDSSRM
c62['HST'].visible = visHST
c62['Nardini'].visible = visNardini

c63 = {}
p63 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, y_range=(-1500,6500))
c63['TimlinClean'] = p63.circle('he2ew', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c63['TimlinOther'] = p63.circle('he2ew', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c63['LussoClean'] = p63.circle('he2ew', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c63['LussoOther'] = p63.circle('he2ew', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c63['SDSSRM'] = p63.circle('he2ew', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c63['HST'] = p63.circle('he2ew', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c63['Nardini'] = p63.circle('he2ew', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c63['Good'] = p63.circle('he2ew', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p63.yaxis.axis_label = 'Delta (g-i)'
p63.xaxis.axis_label = 'log(HeII EQW)'
p63.legend.click_policy="hide"
p63.legend.glyph_height = gheight
p63.legend.spacing = lspace
p63.legend.label_text_font = lfont
p63.legend.label_text_font_size = lsize
p63.legend.label_height = lheight
p63.legend.label_width = lwidth
p63.legend.margin = lmargin
p63.legend.location = 'top_right'
c63['TimlinClean'].visible = visTimlinClean
c63['TimlinOther'].visible = visTimlinOther
c63['LussoClean'].visible = visLussoClean
c63['LussoOther'].visible = visLussoOther
c63['SDSSRM'].visible = visSDSSRM
c63['HST'].visible = visHST
c63['Nardini'].visible = visNardini

#selection_glyph = Circle(fill_color='orange', line_color=None)
#nonselection_glyph = Circle(fill_color='#1f77b4', fill_alpha=0.1, line_color=None)
#r1.selection_glyph = selection_glyph
#r1.nonselection_glyph = nonselection_glyph

c64 = {}
p64 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, x_range=(0.5, -0.5), y_range=(-1500,6500))
c64['TimlinClean'] = p64.circle('gamma', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c64['TimlinOther'] = p64.circle('gamma', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c64['LussoClean'] = p64.circle('gamma', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c64['LussoOther'] = p64.circle('gamma', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c64['SDSSRM'] = p64.circle('gamma', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c64['HST'] = p64.circle('gamma', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c64['Nardini'] = p64.circle('gamma', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c64['Good'] = p64.circle('gamma', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p64.yaxis.axis_label = 'Delta (g-i)'
p64.xaxis.axis_label = 'Gamma'
#p66.x_range.flipped = True
p64.legend.click_policy="hide"
p64.legend.glyph_height = gheight
p64.legend.spacing = lspace
p64.legend.label_text_font = lfont
p64.legend.label_text_font_size = lsize
p64.legend.label_height = lheight
p64.legend.label_width = lwidth
p64.legend.margin = lmargin
p64.legend.location = 'top_right'
c64['TimlinClean'].visible = visTimlinClean
c64['TimlinOther'].visible = visTimlinOther
c64['LussoClean'].visible = visLussoClean
c64['LussoOther'].visible = visLussoOther
c64['SDSSRM'].visible = visSDSSRM
c64['HST'].visible = visHST
c64['Nardini'].visible = visNardini

c65 = {}
p65 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))# x_range=(-2.3,-0.9))#, y_range=(-1500,6500))
c65['TimlinClean'] = p65.circle('aox', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c65['TimlinOther'] = p65.circle('aox', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c65['LussoClean'] = p65.circle('aox', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c65['LussoOther'] = p65.circle('aox', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c65['SDSSRM'] = p65.circle('aox', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c65['HST'] = p65.circle('aox', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c65['Nardini'] = p65.circle('aox', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c65['Good'] = p65.circle('aox', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p65.yaxis.axis_label = 'Delta (g-i)'
p65.xaxis.axis_label = 'alpha_ox'
#p65.x_range.flipped = True
p65.legend.click_policy="hide"
p65.legend.glyph_height = gheight
p65.legend.spacing = lspace
p65.legend.label_text_font = lfont
p65.legend.label_text_font_size = lsize
p65.legend.label_height = lheight
p65.legend.label_width = lwidth
p65.legend.margin = lmargin
p65.legend.location = 'top_right'
c65['TimlinClean'].visible = visTimlinClean
c65['TimlinOther'].visible = visTimlinOther
c65['LussoClean'].visible = visLussoClean
c65['LussoOther'].visible = visLussoOther
c65['SDSSRM'].visible = visSDSSRM
c65['HST'].visible = visHST
c65['Nardini'].visible = visNardini

c66 = {}
p66 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c66['TimlinClean'] = p66.circle('ndaox', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c66['TimlinOther'] = p66.circle('ndaox', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c66['LussoClean'] = p66.circle('ndaox', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c66['LussoOther'] = p66.circle('ndaox', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c66['SDSSRM'] = p66.circle('ndaox', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c66['HST'] = p66.circle('ndaox', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c66['Nardini'] = p66.circle('ndaox', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c66['Good'] = p66.circle('ndaox', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p66.yaxis.axis_label = 'Delta (g-i)'
p66.xaxis.axis_label = 'delta_aox'
#p65.x_range.flipped = True
p66.legend.click_policy="hide"
p66.legend.glyph_height = gheight
p66.legend.spacing = lspace
p66.legend.label_text_font = lfont
p66.legend.label_text_font_size = lsize
p66.legend.label_height = lheight
p66.legend.label_width = lwidth
p66.legend.margin = lmargin
p66.legend.location = 'top_right'
c66['TimlinClean'].visible = visTimlinClean
c66['TimlinOther'].visible = visTimlinOther
c66['LussoClean'].visible = visLussoClean
c66['LussoOther'].visible = visLussoOther
c66['SDSSRM'].visible = visSDSSRM
c66['HST'].visible = visHST
c66['Nardini'].visible = visNardini


c67 = {}
p67 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c67['TimlinClean'] = p67.circle('logL2500', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c67['TimlinOther'] = p67.circle('logL2500', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c67['LussoClean'] = p67.circle('logL2500', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c67['LussoOther'] = p67.circle('logL2500', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c67['SDSSRM'] = p67.circle('logL2500', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c67['HST'] = p67.circle('logL2500', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c67['Nardini'] = p67.circle('logL2500', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c67['Good'] = p67.circle('logL2500', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p67.yaxis.axis_label = 'Delta (g-i)'
p67.xaxis.axis_label = 'logL2500'
#p65.x_range.flipped = True
p67.legend.click_policy="hide"
p67.legend.glyph_height = gheight
p67.legend.spacing = lspace
p67.legend.label_text_font = lfont
p67.legend.label_text_font_size = lsize
p67.legend.label_height = lheight
p67.legend.label_width = lwidth
p67.legend.margin = lmargin
p67.legend.location = 'top_left'
c67['TimlinClean'].visible = visTimlinClean
c67['TimlinOther'].visible = visTimlinOther
c67['LussoClean'].visible = visLussoClean
c67['LussoOther'].visible = visLussoOther
c67['SDSSRM'].visible = visSDSSRM
c67['HST'].visible = visHST
c67['Nardini'].visible = visNardini

c68 = {}
p68 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(-35, -29), y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c68['TimlinClean'] = p68.circle('f2keV', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68['TimlinOther'] = p68.circle('f2keV', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68['LussoClean'] = p68.circle('f2keV', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68['LussoOther'] = p68.circle('f2keV', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68['SDSSRM'] = p68.circle('f2keV', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c68['HST'] = p68.circle('f2keV', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c68['Nardini'] = p68.circle('f2keV', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c68['Good'] = p68.circle('f2keV', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p68.yaxis.axis_label = 'Delta (g-i)'
p68.xaxis.axis_label = 'log f 2keV'
#p65.x_range.flipped = True
p68.legend.click_policy="hide"
p68.legend.glyph_height = gheight
p68.legend.spacing = lspace
p68.legend.label_text_font = lfont
p68.legend.label_text_font_size = lsize
p68.legend.label_height = lheight
p68.legend.label_width = lwidth
p68.legend.margin = lmargin
p68.legend.location = 'top_left'
c68['TimlinClean'].visible = visTimlinClean
c68['TimlinOther'].visible = visTimlinOther
c68['LussoClean'].visible = visLussoClean
c68['LussoOther'].visible = visLussoOther
c68['SDSSRM'].visible = visSDSSRM
c68['HST'].visible = visHST
c68['Nardini'].visible = visNardini

c68b = {}
p68b = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c68b['TimlinClean'] = p68b.circle('c4dist', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68b['TimlinOther'] = p68b.circle('c4dist', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68b['LussoClean'] = p68b.circle('c4dist', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68b['LussoOther'] = p68b.circle('c4dist', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68b['SDSSRM'] = p68b.circle('c4dist', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c68b['HST'] = p68b.circle('c4dist', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c68b['Nardini'] = p68b.circle('c4dist', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c68b['Good'] = p68b.circle('c4dist', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p68b.xaxis.axis_label = 'CIV Distance'
p68b.yaxis.axis_label = 'Delta (g-i)'
#p65.x_range.flipped = True
p68b.legend.click_policy="hide"
p68b.legend.glyph_height = gheight
p68b.legend.spacing = lspace
p68b.legend.label_text_font = lfont
p68b.legend.label_text_font_size = lsize
p68b.legend.label_height = lheight
p68b.legend.label_width = lwidth
p68b.legend.margin = lmargin
p68b.legend.location = 'top_left'
c68b['TimlinClean'].visible = visTimlinClean
c68b['TimlinOther'].visible = visTimlinOther
c68b['LussoClean'].visible = visLussoClean
c68b['LussoOther'].visible = visLussoOther
c68b['SDSSRM'].visible = visSDSSRM
c68b['HST'].visible = visHST
c68b['Nardini'].visible = visNardini


c69 = {}
p69 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c69['TimlinClean'] = p69.circle('logEdd', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c69['TimlinOther'] = p69.circle('logEdd', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c69['LussoClean'] = p69.circle('logEdd', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c69['LussoOther'] = p69.circle('logEdd', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c69['SDSSRM'] = p69.circle('logEdd', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c69['HST'] = p69.circle('logEdd', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c69['Nardini'] = p69.circle('logEdd', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c69['Good'] = p69.circle('logEdd', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p69.yaxis.axis_label = 'Delta (g-i)'
p69.xaxis.axis_label = 'logEdd'
#p65.x_range.flipped = True
p69.legend.click_policy="hide"
p69.legend.glyph_height = gheight
p69.legend.spacing = lspace
p69.legend.label_text_font = lfont
p69.legend.label_text_font_size = lsize
p69.legend.label_height = lheight
p69.legend.label_width = lwidth
p69.legend.margin = lmargin
p69.legend.location = 'top_left'
c69['TimlinClean'].visible = visTimlinClean
c69['TimlinOther'].visible = visTimlinOther
c69['LussoClean'].visible = visLussoClean
c69['LussoOther'].visible = visLussoOther
c69['SDSSRM'].visible = visSDSSRM
c69['HST'].visible = visHST
c69['Nardini'].visible = visNardini

c70 = {}
p70 = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, x_range=(7, 11), y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c70['TimlinClean'] = p70.circle('logBHM', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c70['TimlinOther'] = p70.circle('logBHM', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c70['LussoClean'] = p70.circle('logBHM', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c70['LussoOther'] = p70.circle('logBHM', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c70['SDSSRM'] = p70.circle('logBHM', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c70['HST'] = p70.circle('logBHM', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c70['Nardini'] = p70.circle('logBHM', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c70['Good'] = p70.circle('logBHM', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p70.yaxis.axis_label = 'Delta (g-i)'
p70.xaxis.axis_label = 'logBHM'
#p65.x_range.flipped = True
p70.legend.click_policy="hide"
p70.legend.glyph_height = gheight
p70.legend.spacing = lspace
p70.legend.label_text_font = lfont
p70.legend.label_text_font_size = lsize
p70.legend.label_height = lheight
p70.legend.label_width = lwidth
p70.legend.margin = lmargin
p70.legend.location = 'top_left'
c70['TimlinClean'].visible = visTimlinClean
c70['TimlinOther'].visible = visTimlinOther
c70['LussoClean'].visible = visLussoClean
c70['LussoOther'].visible = visLussoOther
c70['SDSSRM'].visible = visSDSSRM
c70['HST'].visible = visHST
c70['Nardini'].visible = visNardini

c68c = {}
p68c = figure(width=pwidth, plot_height=pheight, tools=TOOLS, tooltips=TOOLTIPS, y_range=(-0.5,1.0))#, x_range=(0.5, -0.7))#, y_range=(-1500,6500))
c68c['TimlinClean'] = p68c.circle('c4perp', 'relgi', source=source1a, legend_label='Timlin Sensitive', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68c['TimlinOther'] = p68c.circle('c4perp', 'relgi', source=source1b, legend_label='Timlin Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68c['LussoClean'] = p68c.circle('c4perp', 'relgi', source=source4a, legend_label='Lusso Clean', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68c['LussoOther'] = p68c.circle('c4perp', 'relgi', source=source4b, legend_label='Lusso Other', size=sizeAll, color=cAll, alpha=0.5, selection_color="orange")
c68c['SDSSRM'] = p68c.circle('c4perp', 'relgi', source=source2, legend_label='SDSSRM', size=sizeAll, color=cRM, alpha=0.5, selection_color="orange")
c68c['HST'] = p68c.circle('c4perp', 'relgi', source=source3, legend_label='Chandra/HST', size=sizeAll, color=cHST, alpha=0.5, selection_color="orange")
c68c['Nardini'] = p68c.circle('c4perp', 'relgi', source=source4c, legend_label='Nardini', size=sizeAll, color=cNard, alpha=0.5, selection_color="orange")
c68c['Good'] = p68c.circle('c4perp', 'relgi', source=sourcegood, legend_label='Good', size=sizeAll, color=cGood, alpha=0.5, selection_color="orange")
p68c.xaxis.axis_label = 'CIV Perp Dist'
p68c.yaxis.axis_label = 'Delta (g-i)'
#p65.x_range.flipped = True
p68c.legend.click_policy="hide"
p68c.legend.glyph_height = gheight
p68c.legend.spacing = lspace
p68c.legend.label_text_font = lfont
p68c.legend.label_text_font_size = lsize
p68c.legend.label_height = lheight
p68c.legend.label_width = lwidth
p68c.legend.margin = lmargin
p68c.legend.location = 'top_left'
c68c['TimlinClean'].visible = visTimlinClean
c68c['TimlinOther'].visible = visTimlinOther
c68c['LussoClean'].visible = visLussoClean
c68c['LussoOther'].visible = visLussoOther
c68c['SDSSRM'].visible = visSDSSRM
c68c['HST'].visible = visHST
c68c['Nardini'].visible = visNardini

# put all the plots in a gridplot
p = gridplot([[p61, p62, p63], [p64, p65, p66], [p67, p68, p68b],  [p69, p70, p68c]], sizing_mode='scale_width')

tab6 = Panel(child = p, title = 'Delta (g-i)')

# %%
ptabs = Tabs(tabs = [tab1, tab2, tab3, tab5, tab6, tab4])

output_file('CIVDistBokehGTR.html')

# show the results
show(ptabs)
